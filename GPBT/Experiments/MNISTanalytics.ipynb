# %%
import pandas as pd
from numpy import genfromtxt
import numpy as np
from scipy.interpolate import *
import matplotlib.pyplot as plt
import math
from scipy.signal import savgol_filter

# %%
hyper = genfromtxt('/home/antoine/Téléchargements/hyperopt.csv', delimiter=',')
fsnv = genfromtxt('/home/antoine/Téléchargements/FSVN.csv', delimiter=',')
random =  genfromtxt('/home/antoine/randomoptMNIST.csv', delimiter=',')



fsnv1 = fsnv[5:,:]
print(fsnv1)
# Out:
# [[0.99632561 0.99989693 0.02915892 ... 0.09467192 0.1176     0.1094    ]
#  [0.90048478 0.99027421 0.98680125 ... 0.00746231 0.1104     0.1166    ]
#  [0.92351379 0.99469083 0.48950417 ... 0.06694034 0.1102     0.1168    ]
#  ...
#  [0.95249728 0.99364613 0.54143975 ... 0.0048772  0.9764     0.9784    ]
#  [0.93670836 0.99291189 0.64894529 ... 0.08524682 0.8516     0.8502    ]
#  [0.95842973 0.99395039 0.46478157 ... 0.01478444 0.9662     0.9638    ]]

# %%
CMA = genfromtxt('/home/antoine/Téléchargements/FSVN_CMA_MNIST.csv', delimiter=',')
#this cell extract the second batch of results
cma1_2 = CMA[1:241,-2:]
cma2_2 = CMA[242:482,-2:]
cma3_2 = CMA[483:723,-2:]
cma4_2 = CMA[724:964,-2:]
cma5_2 = CMA[965:1205,-2:]
cma6_2 = CMA[1206:1446,-2:]
cma7_2 = CMA[1447:1687,-2:]
cma8_2 = CMA[1688:1928,-2:]
cma9_2 = CMA[1929:2169,-2:]
cma10_2 = CMA[2170:2410,-2:]
#loss_test_iteration




maxof(cma1_2)
maxof(cma2_2)
maxof(cma3_2)
maxof(cma4_2)
maxof(cma5_2)
maxof(cma6_2)
maxof(cma7_2)
maxof(cma8_2)
maxof(cma9_2)
maxof(cma10_2)


(xa,xb,xc,xd)= getall(np.concatenate(
    
    (cma1_2,cma2_2,cma3_2,cma4_2,cma5_2
                                   ,cma6_2,cma7_2,cma8_2,cma9_2,cma10_2 )
    ,axis=1)[:240,])
# Out:
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# ...

# %%
hyper_v2 = genfromtxt('/home/antoine/FSN/data_brut/5_MNIST_v2/hyperopt_v2.csv', delimiter=',')
fsnv_v2 = genfromtxt('/home/antoine/FSN/data_brut/5_MNIST_v2/FSVN_2.csv', delimiter=',')

# %%
#this cell extract the second batch of results
hyper1_2 = hyper_v2[1:251,-3:]
hyper2_2 = hyper_v2[251:501,-3:]
hyper3_2 = hyper_v2[501:751,-3:]
hyper4_2 = hyper_v2[751:1001,-3:]
hyper5_2 = hyper_v2[1001:1251,-3:]
#loss_test_iteration
hyper1_2 = hyper1_2[np.argsort(hyper1_2[:,2], axis = -1)][:,-3:-1]
hyper2_2 = hyper2_2[np.argsort(hyper2_2[:,2], axis = -1)][:,-3:-1]
hyper3_2 = hyper3_2[np.argsort(hyper3_2[:,2], axis = -1)][:,-3:-1]
hyper4_2 = hyper4_2[np.argsort(hyper4_2[:,2], axis = -1)][:,-3:-1]
hyper5_2 = hyper5_2[np.argsort(hyper5_2[:,2], axis = -1)][:,-3:-1]

fsnv1_2 = fsnv_v2[1:251,-5:]
fsnv2_2 = fsnv_v2[251:501,-5:]
fsnv3_2 = fsnv_v2[501:751,-5:]
fsnv4_2 = fsnv_v2[751:1001,-5:]
fsnv5_2 = fsnv_v2[1001:1251,-5:]
iteration_corector(fsnv1_2[:,-5],25)
iteration_corector(fsnv2_2[:,-5],25)
iteration_corector(fsnv3_2[:,-5],25)
iteration_corector(fsnv4_2[:,-5],25)
iteration_corector(fsnv5_2[:,-5],25)

#loss_test_iteration
fsnv1_2 = fsnv1_2[np.argsort(fsnv1_2[:,-5], axis = -1)][:,-2:]
fsnv2_2 = fsnv2_2[np.argsort(fsnv2_2[:,-5], axis = -1)][:,-2:]
fsnv3_2 = fsnv3_2[np.argsort(fsnv3_2[:,-5], axis = -1)][:,-2:]
fsnv4_2 = fsnv4_2[np.argsort(fsnv4_2[:,-5], axis = -1)][:,-2:]
fsnv5_2 = fsnv5_2[np.argsort(fsnv5_2[:,-5], axis = -1)][:,-2:]

maxof(hyper1_2)
maxof(hyper2_2)
maxof(hyper3_2)
maxof(hyper4_2)
maxof(hyper5_2)

maxof(fsnv1_2)
maxof(fsnv2_2)
maxof(fsnv3_2)
maxof(fsnv4_2)
maxof(fsnv5_2)
# Out:
# array([[0.8896, 0.8896],
#        [0.8896, 0.8896],
#        [0.937 , 0.9418],
#        [0.937 , 0.9418],
#        [0.9414, 0.9502],
#        [0.9414, 0.9502],
#        [0.9414, 0.9502],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
# ...

# %%
no_iter = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/Test_no_iter.csv', delimiter=',')
no_iter1 = no_iter[1:251,-5:]
no_iter2 = no_iter[251:501,-5:]
no_iter3 = no_iter[501:751,-5:]
no_iter4 = no_iter[751:1001,-5:]
no_iter5 = no_iter[1002:1252,-5:]
iteration_corector(no_iter1[:,-5],25)
iteration_corector(no_iter2[:,-5],25)
iteration_corector(no_iter3[:,-5],25)
iteration_corector(no_iter4[:,-5],25)
iteration_corector(no_iter5[:,-5],25)

#loss_test_iteration
no_iter1 = no_iter1[np.argsort(no_iter1[:,-5], axis = -1)][:,-2:]
no_iter2 = no_iter2[np.argsort(no_iter2[:,-5], axis = -1)][:,-2:]
no_iter3 = no_iter3[np.argsort(no_iter3[:,-5], axis = -1)][:,-2:]
no_iter4 = no_iter4[np.argsort(no_iter4[:,-5], axis = -1)][:,-2:]
no_iter5 = no_iter5[np.argsort(no_iter5[:,-5], axis = -1)][:,-2:]

maxof(no_iter1)
maxof(no_iter2)
maxof(no_iter3)
maxof(no_iter4)
maxof(no_iter5)

plt.plot(no_iter1[:,0])
plt.plot(no_iter2[:,0])
plt.plot(no_iter3[:,0])
plt.plot(no_iter4[:,0])
plt.plot(no_iter5[:,0])
axes = plt.gca()
axes.set_ylim(0.94,.995)
# Out:
# (0.94, 0.995)

# %%
no_iter_more = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/Test_no_iter_but_more4.csv', delimiter=',')
no_iter_more1 = no_iter_more[1:251,-5:]
no_iter_more2 = no_iter_more[251:501,-5:]
no_iter_more3 = no_iter_more[501:751,-5:]
no_iter_more4 = no_iter_more[751:1001,-5:]
no_iter_more5 = no_iter_more[1001:1251,-5:]
iteration_corector(no_iter_more1[:,-5],25)
iteration_corector(no_iter_more2[:,-5],25)
iteration_corector(no_iter_more3[:,-5],25)
iteration_corector(no_iter_more4[:,-5],25)
iteration_corector(no_iter_more5[:,-5],25)

#loss_test_iter_moreation
no_iter_more1 = no_iter_more1[np.argsort(no_iter_more1[:,-5], axis = -1)][:,-2:]
no_iter_more2 = no_iter_more2[np.argsort(no_iter_more2[:,-5], axis = -1)][:,-2:]
no_iter_more3 = no_iter_more3[np.argsort(no_iter_more3[:,-5], axis = -1)][:,-2:]
no_iter_more4 = no_iter_more4[np.argsort(no_iter_more4[:,-5], axis = -1)][:,-2:]
no_iter_more5 = no_iter_more5[np.argsort(no_iter_more5[:,-5], axis = -1)][:,-2:]

maxof(no_iter_more1)
maxof(no_iter_more2)
maxof(no_iter_more3)
maxof(no_iter_more4)
maxof(no_iter_more5)

plt.plot(no_iter_more1[:,0],c='k')
plt.plot(no_iter_more2[:,0],c='k')
plt.plot(no_iter_more3[:,0],c='k')
plt.plot(no_iter_more4[:,0],c='k')
plt.plot(no_iter_more5[:,0],c='k')
plt.plot(no_iter1[:,0])
plt.plot(no_iter2[:,0])
plt.plot(no_iter3[:,0])
plt.plot(no_iter4[:,0])
plt.plot(no_iter5[:,0])
axes = plt.gca()
axes.set_ylim(0.97,.993)
no_iter_more5[0,0]
# Out:
# 0.8986

# %%
no_iter_more = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/FSNV_MNIST_GP.csv', delimiter=',')
no_iter_more1 = no_iter_more[1:251,-5:]
no_iter_more2 = no_iter_more[251:501,-5:]
no_iter_more3 = no_iter_more[501:751,-5:]
no_iter_more4 = no_iter_more[751:1001,-5:]
no_iter_more5 = no_iter_more[1001:1251,-5:]
no_iter_more6 = no_iter_more[1251:250+1251,-5:]
no_iter_more7 = no_iter_more[250+1251:500+1251,-5:]
no_iter_more8 = no_iter_more[500+1251:750+1251,-5:]
no_iter_more9 = no_iter_more[750+1251:1000+1251,-5:]
no_iter_more10 = no_iter_more[1000+1251:1250+1251,-5:]
iteration_corector(no_iter_more1[:,-5],25)
iteration_corector(no_iter_more2[:,-5],25)
iteration_corector(no_iter_more3[:,-5],25)
iteration_corector(no_iter_more4[:,-5],25)
iteration_corector(no_iter_more5[:,-5],25)
iteration_corector(no_iter_more6[:,-5],25)
iteration_corector(no_iter_more7[:,-5],25)
iteration_corector(no_iter_more8[:,-5],25)
iteration_corector(no_iter_more9[:,-5],25)
iteration_corector(no_iter_more10[:,-5],25)
#loss_test_iter_moreation
no_iter_more1 = no_iter_more1[np.argsort(no_iter_more1[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more2 = no_iter_more2[np.argsort(no_iter_more2[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more3 = no_iter_more3[np.argsort(no_iter_more3[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more4 = no_iter_more4[np.argsort(no_iter_more4[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more5 = no_iter_more5[np.argsort(no_iter_more5[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more6 = no_iter_more6[np.argsort(no_iter_more6[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more7 = no_iter_more7[np.argsort(no_iter_more7[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more8 = no_iter_more8[np.argsort(no_iter_more8[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more9 = no_iter_more9[np.argsort(no_iter_more9[:,-5], axis = -1,kind='stable')][:,-2:]
no_iter_more10 = no_iter_more10[np.argsort(no_iter_more10[:,-5], axis = -1,kind='stable')][:,-2:]
maxof(no_iter_more1)
maxof(no_iter_more2)
maxof(no_iter_more3)
maxof(no_iter_more4)
maxof(no_iter_more5)
maxof(no_iter_more6)
maxof(no_iter_more7)
maxof(no_iter_more8)
maxof(no_iter_more9)
maxof(no_iter_more10)

[gp1,gp2,gp3,gp4] = getall(np.concatenate((no_iter_more1,no_iter_more2,no_iter_more3,no_iter_more4,no_iter_more5
                                   ,no_iter_more6,no_iter_more7,no_iter_more8,no_iter_more9,no_iter_more10 ),axis=1)[:250,])

# %%
def iteration_corector(liste, num_config):
    for i in range(len(liste[:])):
        liste[i] = math.floor(i/num_config)

# %%
hyper1 = hyper[1:251,-3:]
hyper2 = hyper[251:501,-3:]
hyper3 = hyper[501:751,-3:]
hyper4 = hyper[751:1001,-3:]
hyper5 = hyper[1001:1251,-3:]
#loss_test_iteration
hyper1 = hyper1[np.argsort(hyper1[:,2], axis = -1)][:,-3:-1]
hyper2 = hyper2[np.argsort(hyper2[:,2], axis = -1)][:,-3:-1]
hyper3 = hyper3[np.argsort(hyper3[:,2], axis = -1)][:,-3:-1]
hyper4 = hyper4[np.argsort(hyper4[:,2], axis = -1)][:,-3:-1]
hyper5 = hyper5[np.argsort(hyper5[:,2], axis = -1)][:,-3:-1]


fsnv1 = fsnv[1:251,-5:]
fsnv2 = fsnv[251:501,-5:]
fsnv3 = fsnv[501:751,-5:]
fsnv4 = fsnv[751:1001,-5:]
fsnv5 = fsnv[1001:1251,-5:]

#loss_test_iteration
fsnv1 = fsnv1[np.argsort(fsnv1[:,-5], axis = -1)][:,-2:]
fsnv2 = fsnv2[np.argsort(fsnv2[:,-5], axis = -1)][:,-2:]
fsnv3 = fsnv3[np.argsort(fsnv3[:,-5], axis = -1)][:,-2:]
fsnv4 = fsnv4[np.argsort(fsnv4[:,-5], axis = -1)][:,-2:]
fsnv5 = fsnv5[np.argsort(fsnv5[:,-5], axis = -1)][:,-2:]


random1 = random[1:251,-3:]
random2 = random[251:501,-3:]
random3 = random[501:751,-3:]
random4 = random[751:1001,-3:]
random5 = genfromtxt('/home/antoine/Téléchargements/randomopt.csv', delimiter=',')[-250:,-3:]
#loss_test_iteration
random1 = random1[np.argsort(random1[:,2], axis = -1)][:,-3:-1]
random2 = random2[np.argsort(random2[:,2], axis = -1)][:,-3:-1]
random3 = random3[np.argsort(random3[:,2], axis = -1)][:,-3:-1]
random4 = random4[np.argsort(random4[:,2], axis = -1)][:,-3:-1]
random5 = random5[np.argsort(random5[:,2], axis = -1)][:,-3:-1]
random5
# Out:
# array([[0.103 , 0.1034],
#        [0.7164, 0.727 ],
#        [0.1044, 0.102 ],
#        [0.9376, 0.9346],
#        [0.8552, 0.856 ],
#        [0.914 , 0.917 ],
#        [0.093 , 0.103 ],
#        [0.1012, 0.1044],
#        [0.9046, 0.8994],
#        [0.1104, 0.1166],
#        [0.8628, 0.8564],
#        [0.9336, 0.932 ],
#        [0.8806, 0.8838],
#        [0.1026, 0.0994],
#        [0.1028, 0.0992],
#        [0.0954, 0.101 ],
#        [0.107 , 0.12  ],
#        [0.8328, 0.84  ],
#        [0.1142, 0.1128],
#        [0.888 , 0.8806],
#        [0.1042, 0.1022],
#        [0.1052, 0.1004],
#        [0.8262, 0.83  ],
#        [0.1174, 0.1096],
#        [0.4086, 0.4128],
#        [0.0962, 0.0954],
#        [0.8508, 0.852 ],
#        [0.0994, 0.097 ],
#        [0.0988, 0.0972],
#        [0.1174, 0.1096],
#        [0.9394, 0.9404],
#        [0.8828, 0.8734],
#        [0.9294, 0.9258],
#        [0.114 , 0.113 ],
#        [0.65  , 0.6626],
#        [0.1068, 0.095 ],
#        [0.1026, 0.0994],
# ...

# %%
def maxof(a):
    ma = 0;
    ta = 0;
    for i in range(250):
        if(a.shape[0]<=i):
            a=np.concatenate((a,(np.array([np.array([ma,ta])]))))
            print(a.shape)
        else:
            if(ma<a[i,0]):
                ta = a[i,1]
            ma = max(ma,a[i,0]) 
            a[i,0] = ma
            a[i,1] = ta
    return a[:250]

# %%
maxof(hyper1)
maxof(hyper2)
maxof(hyper3)
maxof(hyper4)
maxof(hyper5)

maxof(fsnv1)
maxof(fsnv2)
maxof(fsnv3)
maxof(fsnv4)
maxof(fsnv5)

maxof(random1)
maxof(random2)
maxof(random3)
maxof(random4)
maxof(random5)
random1
# Out:
# array([[0.1118, 0.1152],
#        [0.8038, 0.7974],
#        [0.8038, 0.7974],
#        [0.9288, 0.9348],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
#        [0.9546, 0.9548],
# ...

# %%
cma = genfromtxt('/home/antoine/Téléchargements/FSVN_CMA_MNIST.csv', delimiter=',')
temp = []
def maxof(a):
    ma = 0;
    ta = 0;
    for i in range(241):
        if(a.shape[0]<=i):
            a=np.concatenate((a,(np.array([np.array([ma,ta])]))))
            print(a.shape)
        else:
            if(ma<a[i,0]):
                ta = a[i,1]
            ma = max(ma,a[i,0]) 
            a[i,0] = ma
            a[i,1] = ta
    return a[:240] 
for i in range(10):
    temp.append(-cma[24*10*i+i+1:24*10*(i+1)+i+1,-2:])
cma1 = maxof( temp[0])
cma2 = maxof( temp[1])
cma3 = maxof( temp[2])
cma4 = maxof( temp[3])
cma5 = maxof( temp[4])
cma6 = maxof( temp[5])
cma7 = maxof( temp[6])
cma8 = maxof( temp[7])
cma9 = maxof( temp[8])
cma10 = maxof( temp[9])
[xa,xb,xc,xd] = getall(np.concatenate((cma1,cma2,cma3,cma4,cma5,cma6,cma7,cma8,cma9,cma10),axis=1))
axes = plt.gca()
plt.plot(xa,c='b')

plt.plot(xc,c='k')
# Out:
# (241, 2)
# (241, 2)
# (241, 2)
# (241, 2)
# (241, 2)
# (241, 2)
# (241, 2)
# (241, 2)
# (241, 2)
# (241, 2)

# %%
def getall(a):
    f = [b for b in a[:,1::2].mean(1)]
    g = [b for b in a[:,0::2].mean(1)]
    def h(x):
        return savgol_filter(np.ravel(x),3, 1)
    return (h(f), h(a[:,1::2].std(1)/2),
            h(g), h(a[:,0::2].std(1)/2))

# %%
[it,jt,kt,lt] = getall(np.concatenate((pbt1,pbt2,pbt3,pbt4,pbt5),axis=1)[:250,])
[m,n,o,p] = getall(np.concatenate((b1,b2,b3,b4,b5,b6,b7,b8,b9,b10),axis=1)[:115,])
[v,w,x,y] = getall(np.concatenate((no_iter_more1,no_iter_more2,no_iter_more3,no_iter_more4,no_iter_more5
                                   ,no_iter1,no_iter2,no_iter3,no_iter4,no_iter5 ),axis=1)[:250,])


print(len(getall(np.concatenate((b1,b2,b3,b4,b5,b6,b7,b8,b9,b10),axis=1))[0]))
# Out:
# 250

# %%
[gp1,gp2,gp3,gp4] = getall(np.concatenate((no_iter_more1,no_iter_more2,no_iter_more3,no_iter_more4,no_iter_more5
                                   ,no_iter_more6,no_iter_more7,no_iter_more8,no_iter_more9,no_iter_more10 ),axis=1)[:250,])

[xa,xb,xc,xd] = getall(np.concatenate((cma1,cma2,cma3,cma4,cma5,cma6,cma7,cma8,cma9,cma10),axis=1))


(xa,xb,xc,xd)= getall(np.concatenate(
    
    (cma1_2,cma2_2,cma3_2,cma4_2,cma5_2
                                   ,cma6_2,cma7_2,cma8_2,cma9_2,cma10_2 )
    ,axis=1)[:240,])




[it,jt,kt,lt] = getall(np.concatenate((pbt1,pbt2,pbt3,pbt4,pbt5),axis=1)[:250,])
[m,n,o,p] = getall(np.concatenate((b1,b2,b3,b4,b5,b6,b7,b8,b9,b10),axis=1)[:115,])
[v,w,x,y] = getall(np.concatenate((no_iter_more1,no_iter_more2,no_iter_more3,no_iter_more4,no_iter_more5
                                   ,no_iter1,no_iter2,no_iter3,no_iter4,no_iter5 ),axis=1)[:250,])


print(len(getall(np.concatenate((b1,b2,b3,b4,b5,b6,b7,b8,b9,b10),axis=1))[0]))
[a,b,c,d] = getall(np.concatenate((fsnv1,fsnv2,fsnv3,fsnv4,fsnv5),axis=1))
[e,f,g,h] = getall(np.concatenate((hyper1,hyper2,hyper3,hyper4,hyper5,
                                  hyper1_2,hyper2_2,hyper3_2,hyper4_2,hyper5_2),axis=1))

[i_3,j_3,k_3,l_3] = getall(np.concatenate((pb1,pb2,pb3,pb4,pb5,pb1_2,pb2_2,pb3_2,pb4_2),axis=1))

#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

t= np.arange(0,250)*1625/250
#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')
#np.savetxt('our_new.csv', np.array([t,q,r,s,u]).T, delimiter=',')
t= np.arange(0,250)*1525/250

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
t= np.arange(0,250)*2308/250*.8
#np.savetxt('pb2.csv', np.array([t,i_3,j_3,k_3,l_3]).T, delimiter=',')
# Out:
# 250

# %%
[fa,fb,fc,fd] = getall(np.concatenate((fsnv1,fsnv2,fsnv3,fsnv4,fsnv5,fsnv1_2,fsnv2_2,fsnv3_2,fsnv4_2,fsnv5_2),axis=1)[:250,])

# %%
plt.plot(np.concatenate((no_iter_more1,no_iter_more2,no_iter_more3,no_iter_more4,no_iter_more5),axis=1))

# %%
t= np.arange(0,250)*1625/250
np.savetxt('Mnist_tpe_no_time.csv', np.array([t,v,w,x,y]).T, delimiter=' ')

# %%
[a,b,c,d] = getall(np.concatenate((fsnv1,fsnv2,fsnv3,fsnv4,fsnv5),axis=1))
[e,f,g,h] = getall(np.concatenate((hyper1,hyper2,hyper3,hyper4,hyper5,
                                  hyper1_2,hyper2_2,hyper3_2,hyper4_2,hyper5_2),axis=1))

[i_3,j_3,k_3,l_3] = getall(np.concatenate((pb1,pb2,pb3,pb4,pb5,pb1_2,pb2_2,pb3_2,pb4_2),axis=1))

#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

t= np.arange(0,250)*1625/250
#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')
#np.savetxt('our_new.csv', np.array([t,q,r,s,u]).T, delimiter=',')
t= np.arange(0,250)*1525/250

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
t= np.arange(0,250)*2308/250*.8
#np.savetxt('pb2.csv', np.array([t,i_3,j_3,k_3,l_3]).T, delimiter=',')

# %%
t= np.arange(0,250)*1629/250
#np.savetxt('pbt_mnist.csv', np.array([it,jt,kt,lt]).T, delimiter=' ')

t= np.arange(0,115)*773/115
#np.savetxt('BOHB_mnist.csv', np.array([m,n,o,p]).T, delimiter=' ')

# %%
[q,r,s,u] = getall(np.concatenate((fsnv1_2,fsnv2_2,fsnv3_2,fsnv4_2,fsnv5_2),axis=1))
t= np.arange(0,250)*1625/250
plt.plot(t,fc,color=(0,0,1),label = "Our approach time-TPE \n /wo parent backroll")
plt.fill_between(t, fc-fd,  fc+fd, alpha = 0.2,color=(0,0,1))


t= np.arange(0,250)*1525/250
plt.plot(t,g,color=(0,1,0),label="hyperopt")
plt.fill_between(t, g-h,  g+h, alpha = 0.2,color=(0,1,0))


t= np.arange(0,250)*2308/250*.8
plt.plot(t,k_3,color=(1,0,0),label="PB2, state of the art v2")
plt.fill_between(t, k_3-l_3,  k_3+l_3, alpha = 0.2,color=(1,0,0))


t= np.arange(0,250)*1625/250
#plt.plot(t,s,color='c',label="our approach time-TPE")
#plt.fill_between(t, s-u,  s+u, alpha = 0.3,color='c')

t= np.arange(0,250)*1625/250
plt.plot(t,x,color=(1,.8,0),label="our approach TPE")
plt.fill_between(t, x-y,  x+y, alpha = 0.2,color=(1,.8,0))

t= np.arange(0,250)*1625/250
plt.plot(t,gp3,color=(.33,1,.66),label="our approach time-GP")
plt.fill_between(t, gp3-gp4,  gp3+gp4, alpha = 0.2,color=(.33,1,.66))

t= np.arange(0,240)*1625/250
plt.plot(t,xc,color=(0,0,0),label="our approach CMA")
plt.fill_between(t, xc-xd,  xc+xd, alpha = 0.2,color=(0,0,0))



t= np.arange(0,250)*1629/250
plt.plot(t,kt,color=(1,0,1),label="PBT")
plt.fill_between(t, kt-lt,  kt+lt, alpha = 0.2,color=(1,0,1))


t= np.arange(0,115)*773/115
plt.plot(t,o,color=(0,1,1),label="BOHB")
plt.fill_between(t, o-p,  o+p, alpha = 0.2,color=(0,1,1))
#plt.legend(bbox_to_anchor=(1.38,0.005 ), loc='lower right', borderaxespad=0.,ncol = 1)



axes = plt.gca()
axes.set_ylim(0.93,.992)
axes.set_xlim(0.1,1850)
axes.set_xlabel('execution time (s)',fontsize=16)
axes.set_ylabel('accuracy',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#axes.set_title('Comparison on val data of MNIST with 10 experiment')
axes.plot([0,1,2], [10,20,3])
fig = plt.gcf()
fig.set_size_inches(6, 4)
plt.tight_layout()
plt.savefig('MNIST6.pdf')
plt.show()

# %%
[q,r,s,u] = getall(np.concatenate((fsnv1_2,fsnv2_2,fsnv3_2,fsnv4_2,fsnv5_2),axis=1))
t= np.arange(0,250)*1625/250
plt.plot(t,fa,color=(0,0,1),label = "Our approach time-TPE \n /wo parent backroll")
plt.fill_between(t, fa-fb,  fa+fb, alpha = 0.2,color=(0,0,1))


t= np.arange(0,250)*1525/250
plt.plot(t,e,color=(0,1,0),label="hyperopt")
plt.fill_between(t, e-f,  e+f, alpha = 0.2,color=(0,1,0))


t= np.arange(0,250)*2308/250*.8
plt.plot(t,i_3,color=(1,0,0),label="PB2, state of the art v2")
plt.fill_between(t, i_3-j_3,  i_3+j_3, alpha = 0.2,color=(1,0,0))


t= np.arange(0,250)*1625/250
#plt.plot(t,q,color=(0,1,1),label="our approach time-TPE")
#plt.fill_between(t, q-r,  q+r, alpha = 0.3,color=(0,1,1))


t= np.arange(0,250)*1625/250
plt.plot(t,v,color=(1,.8,0),label="our approach TPE")
plt.fill_between(t, v-w,  v+w, alpha = 0.2,color=(1,.8,0))

t= np.arange(0,240)*1625/250
plt.plot(t,xa,color=(0,0,0),label="our approach CMA")
plt.fill_between(t, xa-xb,  xa+xb, alpha = 0.2,color='lime')



t= np.arange(0,250)*1629/250
plt.plot(t,kt,color=(1,0,1),label="PBT")
plt.fill_between(t, kt-lt,  kt+lt, alpha = 0.2,color=(1,0,1))


t= np.arange(0,115)*773/115
plt.plot(t,o,color=(0,1,1),label="BOHB")
plt.fill_between(t, o-p,  o+p, alpha = 0.2,color=(0,1,1))
#plt.legend(bbox_to_anchor=(1.38,0.005 ), loc='lower right', borderaxespad=0.,ncol = 1)


axes = plt.gca()
axes.set_ylim(0.93,.992)
axes.set_xlim(0.1,1850)
axes.set_xlabel('execution time (s)',fontsize=16)
axes.set_ylabel('accuracy',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#axes.set_title('Comparison on test data of MNIST with 10 experiment')
#plt.title(r'\underline{Validation loss}:')
fig = plt.gcf()
fig.set_size_inches(6, 4)
plt.tight_layout()
plt.savefig('MNIST5.pdf')

fig = plt.figure()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

[q,r,s,u] = getall(np.concatenate((fsnv1_2,fsnv2_2,fsnv3_2,fsnv4_2,fsnv5_2),axis=1))
t= np.arange(0,250)*1625/250
ax1.plot(t,fc,color=(0,0,1),label = "Our approach time-TPE \n /wo parent backroll")
ax1.fill_between(t, fc-fd,  fc+fd, alpha = 0.2,color=(0,0,1))


t= np.arange(0,250)*1525/250
ax1.plot(t,g,color=(0,1,0),label="hyperopt")
ax1.fill_between(t, g-h,  g+h, alpha = 0.2,color=(0,1,0))


t= np.arange(0,250)*2308/250*.8
ax1.plot(t,k_3,color=(1,0,0),label="PB2, state of the art v2")
ax1.fill_between(t, k_3-l_3,  k_3+l_3, alpha = 0.2,color=(1,0,0))


t= np.arange(0,250)*1625/250
#plt.plot(t,s,color='c',label="our approach time-TPE")
#plt.fill_between(t, s-u,  s+u, alpha = 0.3,color='c')

t= np.arange(0,250)*1625/250
ax1.plot(t,x,color=(1,.8,0),label="our approach TPE")
ax1.fill_between(t, x-y,  x+y, alpha = 0.2,color=(1,.8,0))

t= np.arange(0,250)*1625/250
ax1.plot(t,gp3,color=(.33,1,.66),label="our approach time-GP")
ax1.fill_between(t, gp3-gp4,  gp3+gp4, alpha = 0.2,color=(.33,1,.66))

t= np.arange(0,240)*1625/250
ax1.plot(t,xc,color=(0,0,0),label="our approach CMA")
ax1.fill_between(t, xc-xd,  xc+xd, alpha = 0.2,color=(0,0,0))



t= np.arange(0,250)*1629/250
ax1.plot(t,kt,color=(1,0,1),label="PBT")
ax1.fill_between(t, kt-lt,  kt+lt, alpha = 0.2,color=(1,0,1))


t= np.arange(0,115)*773/115
ax1.plot(t,o,color=(0,1,1),label="BOHB")
ax1.fill_between(t, o-p,  o+p, alpha = 0.2,color=(0,1,1))
#plt.legend(bbox_to_anchor=(1.38,0.005 ), loc='lower right', borderaxespad=0.,ncol = 1)



axes = ax1

ax1.set_xticks([0,500,1000, 1500])
ax1.set_xticklabels([0,500, 1000,1500],fontsize=18)
ax1.set_yticks([.93,.96,.99])
ax1.set_yticklabels([.93,.96,.99],fontsize=18)


axes.set_ylim(0.93,.992)
axes.set_xlim(0.1,1850)
axes.set_xlabel('execution time (s)',fontsize=18)
axes.set_ylabel('accuracy',fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
#axes.set_title('Comparison on val data of MNIST with 10 experiment')

[q,r,s,u] = getall(np.concatenate((fsnv1_2,fsnv2_2,fsnv3_2,fsnv4_2,fsnv5_2),axis=1))
t= np.arange(0,250)*1625/250
ax2.plot(t,fa,color=(0,0,1),label = "Our approach time-TPE \n /wo parent backroll")
ax2.fill_between(t, fa-fb,  fa+fb, alpha = 0.2,color=(0,0,1))


t= np.arange(0,250)*1525/250
ax2.plot(t,e,color=(0,1,0),label="hyperopt")
ax2.fill_between(t, e-f,  e+f, alpha = 0.2,color=(0,1,0))


t= np.arange(0,250)*2308/250*.8
ax2.plot(t,i_3,color=(1,0,0),label="PB2, state of the art v2")
ax2.fill_between(t, i_3-j_3,  i_3+j_3, alpha = 0.2,color=(1,0,0))


t= np.arange(0,250)*1625/250
#plt.plot(t,q,color=(0,1,1),label="our approach time-TPE")
#plt.fill_between(t, q-r,  q+r, alpha = 0.3,color=(0,1,1))


t= np.arange(0,250)*1625/250
ax2.plot(t,v,color=(1,.8,0),label="our approach TPE")
ax2.fill_between(t, v-w,  v+w, alpha = 0.2,color=(1,.8,0))

t= np.arange(0,240)*1625/250
ax2.plot(t,xa,color=(0,0,0),label="our approach CMA")
ax2.fill_between(t, xa-xb,  xa+xb, alpha = 0.2,color='lime')



t= np.arange(0,250)*1629/250
ax2.plot(t,kt,color=(1,0,1),label="PBT")
ax2.fill_between(t, kt-lt,  kt+lt, alpha = 0.2,color=(1,0,1))


t= np.arange(0,115)*773/115
ax2.plot(t,o,color=(0,1,1),label="BOHB")
ax2.fill_between(t, o-p,  o+p, alpha = 0.2,color=(0,1,1))
#plt.legend(bbox_to_anchor=(1.38,0.005 ), loc='lower right', borderaxespad=0.,ncol = 1)


axes = ax2
axes.set_ylim(0.93,.992)
axes.set_xlim(0.1,1850)
axes.set_xlabel('execution time (s)',fontsize=18)

ax2.set_xticks([0,500,1000, 1500])
ax2.set_xticklabels([0,500, 1000,1500],fontsize=18)
ax2.set_yticks([])


fig.tight_layout()
plt.subplots_adjust(wspace=0,left = .06, right = .999,bottom=0.15,top = .95)


fig.set_size_inches(16, 4)


fig.savefig('MNIST_all.pdf')

# %%
import pandas as pd
from numpy import genfromtxt
import numpy as np
from scipy.interpolate import *
import matplotlib.pyplot as plt


def fonc(data):
    itera = data[:,5:6]
    itera= itera[~np.isnan(itera)]
    dat = data[:,0:2]
    dat = dat[~np.isnan(dat)]
    dat = dat.reshape(-1,2)
    dat = dat[np.argsort(itera,axis=-1)]
    return dat

pb2 = genfromtxt('/home/antoine/Téléchargements/PB2.csv', delimiter=',')
pb2_2 = genfromtxt('/home/antoine/Téléchargements/PB2_v2.csv', delimiter=',')

pb1 = pb2[0:242,:]
pb2t = pb2[242:457]
pb3 = pb2[457:701]
pb4 = pb2[701:-1]

pb1 = fonc(pb1)
pb2 = fonc(pb2t)
pb3 = fonc(pb3)
pb4 = fonc(pb4)

pb5_iter = pb2_2[:,5:6]
pb5_iter= pb5_iter[~np.isnan(pb5_iter)]
#pb5_iter = pb5_iter.reshape(-1,1) 

pb5 = pb2_2[:,0:2]
pb5 = pb5[~np.isnan(pb5)]
pb5 = pb5.reshape(-1,2)
pb5 = pb5[np.argsort(pb5_iter,axis=-1)]

pb1= maxof(pb1)
pb2=maxof(pb2)
pb3=maxof(pb3)
pb4=maxof(pb4)
pb5=maxof(pb5)
pb1= np.array(pb1)
pb2 = np.array(pb2)
#print(pb1.shape)
# Out:
# (218, 2)
# (219, 2)
# (220, 2)
# (221, 2)
# (222, 2)
# (223, 2)
# (224, 2)
# (225, 2)
# (226, 2)
# (227, 2)
# (228, 2)
# (229, 2)
# (230, 2)
# (231, 2)
# (232, 2)
# (233, 2)
# (234, 2)
# (235, 2)
# (236, 2)
# (237, 2)
# (238, 2)
# (239, 2)
# (240, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (191, 2)
# (192, 2)
# (193, 2)
# (194, 2)
# (195, 2)
# (196, 2)
# (197, 2)
# (198, 2)
# (199, 2)
# (200, 2)
# (201, 2)
# (202, 2)
# (203, 2)
# (204, 2)
# (205, 2)
# (206, 2)
# (207, 2)
# (208, 2)
# (209, 2)
# (210, 2)
# (211, 2)
# (212, 2)
# (213, 2)
# (214, 2)
# (215, 2)
# (216, 2)
# (217, 2)
# (218, 2)
# (219, 2)
# (220, 2)
# (221, 2)
# (222, 2)
# (223, 2)
# (224, 2)
# (225, 2)
# (226, 2)
# (227, 2)
# (228, 2)
# (229, 2)
# (230, 2)
# (231, 2)
# (232, 2)
# (233, 2)
# (234, 2)
# (235, 2)
# (236, 2)
# (237, 2)
# (238, 2)
# (239, 2)
# (240, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# ...

# %%
import pandas as pd
from numpy import genfromtxt
import numpy as np
from scipy.interpolate import *
import matplotlib.pyplot as plt


def fonc(data):
    itera = data[:,5:6]
    itera= itera[~np.isnan(itera)]
    dat = data[:,0:2]
    dat = dat[~np.isnan(dat)]
    dat = dat.reshape(-1,2)
    dat = dat[np.argsort(itera,axis=-1)]
    return dat

pb2_v2 = genfromtxt('/home/antoine/FSN/data_brut/5_MNIST_v2/PB2_2.csv', delimiter=',')
pb2_v3 = genfromtxt('/home/antoine/FSN/data_brut/5_MNIST_v2/PB2_2_2.csv', delimiter=',')
pb2_v4 = genfromtxt('/home/antoine/FSN/data_brut/5_MNIST_v2/PB2_2_3.csv', delimiter=',')
pb2_v5 = genfromtxt('/home/antoine/FSN/data_brut/5_MNIST_v2/PB2_2_6.csv', delimiter=',')

pb1_2 = fonc(pb2_v2)
pb2_2 = fonc(pb2_v3)
pb3_2 = fonc(pb2_v4)
pb4_2 = fonc(pb2_v5)

#pb5_iter = pb2_2[:,5:6]
#pb5_iter= pb5_iter[~np.isnan(pb5_iter)]
#pb5_iter = pb5_iter.reshape(-1,1) 

#pb5 = pb2_2[:,0:2]
#pb5 = pb5[~np.isnan(pb5)]
#pb5 = pb5.reshape(-1,2)
#pb5 = pb5[np.argsort(pb5_iter,axis=-1)]

pb1_2= maxof(pb1_2)
pb2_2=maxof(pb2_2)
pb3_2=maxof(pb3_2)
pb4_2=maxof(pb4_2)
#pb5=maxof(pb5)

# %%
np.shape(pb2_2)
# Out:
# (250, 2)

# %%
fsnv_v2 = genfromtxt('/home/antoine/FSN/data_brut/5_MNIST_v2/FSVN_2.csv', delimiter=',')
fsnv1_2 = fsnv_v2[1:251,-5:]
fsnv2_2 = fsnv_v2[251:501,-5:]
fsnv3_2 = fsnv_v2[501:751,-5:]
fsnv4_2 = fsnv_v2[751:1001,-5:]
fsnv5_2 = fsnv_v2[1001:1251,-5:]
iteration_corector(fsnv1_2[:,-5],25)
iteration_corector(fsnv2_2[:,-5],25)
iteration_corector(fsnv3_2[:,-5],25)
iteration_corector(fsnv4_2[:,-5],25)
iteration_corector(fsnv5_2[:,-5],25)

#loss_test_iteration
fsnv1_2 = fsnv1_2[np.argsort(fsnv1_2[:,-5], axis = -1)][:,-2:]
fsnv2_2 = fsnv2_2[np.argsort(fsnv2_2[:,-5], axis = -1)][:,-2:]
fsnv3_2 = fsnv3_2[np.argsort(fsnv3_2[:,-5], axis = -1)][:,-2:]
fsnv4_2 = fsnv4_2[np.argsort(fsnv4_2[:,-5], axis = -1)][:,-2:]
fsnv5_2 = fsnv5_2[np.argsort(fsnv5_2[:,-5], axis = -1)][:,-2:]

maxof(fsnv1_2)
maxof(fsnv2_2)
maxof(fsnv3_2)
maxof(fsnv4_2)
maxof(fsnv5_2)
# Out:
# array([[0.8896, 0.8896],
#        [0.8896, 0.8896],
#        [0.937 , 0.9418],
#        [0.937 , 0.9418],
#        [0.9414, 0.9502],
#        [0.9414, 0.9502],
#        [0.9414, 0.9502],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9518, 0.9422],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
#        [0.9636, 0.9584],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import time

def func(x,b,c,d,f,e):
   # x=x+1e-4
    return  np.exp(-b * x + d) + c + (e**2 )/(f+x)

te = time.time()
popt, pcov = curve_fit(func, np.arange(1,251), -fsnv2_2[:,0],maxfev=10000)
print(time.time()-te)
plt.plot(-fsnv2_2[:,0])
plt.plot(func(np.arange(1,251), *popt))
func(251,*popt)
axes = plt.gca()
axes.set_ylim(-0.955,-.986)
fsnv2_2.shape
# Out:
# 0.01252603530883789
# /home/antoine/.local/lib/python3.6/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
# (250, 2)

# %%
alli = np.array([1,2,3,4,5])

popt, pcov = curve_fit(func, np.arange(1,6), alli,maxfev=10000)
# Out:
# /home/antoine/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:787: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
b1 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[207:322,:]
b2 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[0:92,:]
b3 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[322:437,:]
b4 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[437:552,:]
b5 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[552:668,:]
b6 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[668:782,:]
b7 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[782:897,:]
b8 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[897:1012,:]
b9 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[1012:1127,:]
b10 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/BOHB_Boston1.csv', delimiter=',')[92:207,:]

b1 = fonc(b1)
b2 = fonc(b2)
b3 = fonc(b3)
b4 = fonc(b4)
b5 = fonc(b5)
b6 = fonc(b6)
b7 = fonc(b7)
b8 = fonc(b8)
b9 = fonc(b9)
b10 = fonc(b10)


b1= maxof(b1)
b2=maxof(b2)
b3=maxof(b3)
b4=maxof(b4)
b5=maxof(b5)
b6= maxof(b6)
b7=maxof(b7)
b8=maxof(b8)
b9=maxof(b9)
b10=maxof(b10)
# Out:
# (91, 2)
# (92, 2)
# (93, 2)
# (94, 2)
# (95, 2)
# (96, 2)
# (97, 2)
# (98, 2)
# (99, 2)
# (100, 2)
# (101, 2)
# (102, 2)
# (103, 2)
# (104, 2)
# (105, 2)
# (106, 2)
# (107, 2)
# (108, 2)
# (109, 2)
# (110, 2)
# (111, 2)
# (112, 2)
# (113, 2)
# (114, 2)
# (115, 2)
# (116, 2)
# (117, 2)
# (118, 2)
# (119, 2)
# (120, 2)
# (121, 2)
# (122, 2)
# (123, 2)
# (124, 2)
# (125, 2)
# (126, 2)
# (127, 2)
# (128, 2)
# (129, 2)
# (130, 2)
# (131, 2)
# (132, 2)
# (133, 2)
# (134, 2)
# (135, 2)
# (136, 2)
# (137, 2)
# (138, 2)
# (139, 2)
# (140, 2)
# (141, 2)
# (142, 2)
# (143, 2)
# (144, 2)
# (145, 2)
# (146, 2)
# (147, 2)
# (148, 2)
# (149, 2)
# (150, 2)
# (151, 2)
# (152, 2)
# (153, 2)
# (154, 2)
# (155, 2)
# (156, 2)
# (157, 2)
# (158, 2)
# (159, 2)
# (160, 2)
# (161, 2)
# (162, 2)
# (163, 2)
# (164, 2)
# (165, 2)
# (166, 2)
# (167, 2)
# (168, 2)
# (169, 2)
# (170, 2)
# (171, 2)
# (172, 2)
# (173, 2)
# (174, 2)
# (175, 2)
# (176, 2)
# (177, 2)
# (178, 2)
# (179, 2)
# (180, 2)
# (181, 2)
# ...

# %%
import pandas as pd
from numpy import genfromtxt
import numpy as np
from scipy.interpolate import *
import matplotlib.pyplot as plt


def fonc(data):
    itera = data[:,5:6]
    itera= itera[~np.isnan(itera)]
    dat = data[:,0:2]
    dat = dat[~np.isnan(dat)]
    dat = dat.reshape(-1,2)
  #  dat = dat[np.argsort(itera,axis=-1)]
    return dat

pbt1 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/PBT1.csv', delimiter=',')
pbt2 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/PBT2.csv', delimiter=',')
pbt3 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/PBT3.csv', delimiter=',')
pbt4 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/PBT4.csv', delimiter=',')
pbt5 = genfromtxt('/home/antoine/FSN/data_brut/MNIST_v3/PBT5.csv', delimiter=',')





pbt1 = fonc(pbt1)
pbt2 = fonc(pbt2)
pbt3 = fonc(pbt3)
pbt4 = fonc(pbt4)
pbt5 = fonc(pbt5)



pbt1= maxof(pbt1)
pbt2=maxof(pbt2)
pbt3=maxof(pbt3)
pbt4=maxof(pbt4)
pbt5=maxof(pbt5)
# Out:
# (224, 2)
# (225, 2)
# (226, 2)
# (227, 2)
# (228, 2)
# (229, 2)
# (230, 2)
# (231, 2)
# (232, 2)
# (233, 2)
# (234, 2)
# (235, 2)
# (236, 2)
# (237, 2)
# (238, 2)
# (239, 2)
# (240, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (231, 2)
# (232, 2)
# (233, 2)
# (234, 2)
# (235, 2)
# (236, 2)
# (237, 2)
# (238, 2)
# (239, 2)
# (240, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (210, 2)
# (211, 2)
# (212, 2)
# (213, 2)
# (214, 2)
# (215, 2)
# (216, 2)
# (217, 2)
# (218, 2)
# (219, 2)
# (220, 2)
# (221, 2)
# (222, 2)
# (223, 2)
# (224, 2)
# (225, 2)
# (226, 2)
# (227, 2)
# (228, 2)
# (229, 2)
# (230, 2)
# (231, 2)
# (232, 2)
# (233, 2)
# (234, 2)
# (235, 2)
# (236, 2)
# (237, 2)
# (238, 2)
# (239, 2)
# (240, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (223, 2)
# (224, 2)
# ...

# %%
# Out:
# 0.890275

# %%
# Out:
# 0.890275
# 0.88805
# 0.88305
# 0.884175
# 0.8876999999999999
# 0.8829750000000001
# 0.884625

# %%
# Out:
# (128,)

# %%
plt.plot(t, mean_test_4, 'k-',label="test NeverGrad")
plt.fill_between(t, mean_test_4-std_test_4,  mean_test_4+std_test_4, alpha = 0.2,color='k')

plt.plot(t, mean_val_4, 'k--',label="val NeverGrad")
plt.fill_between(t, mean_val_4-std_val_4,  mean_val_4+std_val_4, alpha = 0.2,color='k')

plt.plot(t, mean_test_6, 'r-',label="test random")
plt.fill_between(t, mean_test_6-std_test_6,  mean_test_6+std_test_6, alpha = 0.2,color='r')

plt.plot(t, mean_val_6, 'r--',label="val random")
plt.fill_between(t, mean_val_6-std_val_6,  mean_val_6+std_val_6, alpha = 0.2,color='r')


axes = plt.gca()
axes.set_ylim(0.78,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('loss')
plt.savefig('109.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_1, 'k-',label="test hyper")
plt.fill_between(t, mean_test_1-std_test_1,  mean_test_1+std_test_1, alpha = 0.2,color='k')

plt.plot(t, mean_val_1, 'b--',label="val hyper")
plt.fill_between(t, mean_val_1-std_val_1,  mean_val_1+std_val_1, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.85,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/304.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_2, 'k-',label="test bayes")
plt.fill_between(t, mean_test_2-std_test_2,  mean_test_2+std_test_2, alpha = 0.2,color='k')

plt.plot(t, mean_val_2, 'b--',label="val bayes")
plt.fill_between(t, mean_val_2-std_val_2,  mean_val_2+std_val_2, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.85,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/305.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_3, 'k-',label="test ax")
plt.fill_between(t, mean_test_3-std_test_3,  mean_test_3+std_test_3, alpha = 0.2,color='k')

plt.plot(t, mean_val_3, 'b--',label="val ax")
plt.fill_between(t, mean_val_3-std_val_3,  mean_val_3+std_val_3, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.78,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/5.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_4, 'k-',label="test NeverGrad")
plt.fill_between(t, mean_test_4-std_test_4,  mean_test_4+std_test_4, alpha = 0.2,color='k')

plt.plot(t, mean_val_4, 'b--',label="val NeverGrad")
plt.fill_between(t, mean_val_4-std_val_4,  mean_val_4+std_val_4, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.006,0.018)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/124.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_5, 'k-',label="test bohb")
plt.fill_between(t, mean_test_5-std_test_5,  mean_test_5+std_test_5, alpha = 0.2,color='k')

plt.plot(t, mean_val_5, 'b--',label="val bohb")
plt.fill_between(t, mean_val_5-std_val_5,  mean_val_5+std_val_5, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.85,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/306.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_6, 'k-',label="test random")
plt.fill_between(t, mean_test_6-std_test_6,  mean_test_6+std_test_6, alpha = 0.2,color='k')

plt.plot(t, mean_val_6, 'b--',label="val random")
plt.fill_between(t, mean_val_6-std_val_6,  mean_val_6+std_val_6, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.85,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/307.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_7, 'k-',label="test zoopt")
plt.fill_between(t, mean_test_7-std_test_7,  mean_test_7+std_test_7, alpha = 0.2,color='k')

plt.plot(t, mean_val_7, 'b--',label="val zoopt")
plt.fill_between(t, mean_val_7-std_val_7,  mean_val_7+std_val_7, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.006,0.018)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/127.png')

fig = plt.figure()
plt.show()
