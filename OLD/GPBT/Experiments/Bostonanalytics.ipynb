# %%
import pandas as pd
from numpy import genfromtxt
import numpy as np
from scipy.interpolate import *
import matplotlib.pyplot as plt
import math

# %%
rnd = genfromtxt('/home/antoine/GPBT/FSN/random_Boston.csv', delimiter=',')

hyper = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston2/Boston_HyperOpt.csv', delimiter=',')
fsnv = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston/FSVN_2.csv', delimiter=',') #was c=2
fsnv_4 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston/FSVN_2_4.csv', delimiter=',')
fsnv_14 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston/FSVN_2_1-4.csv', delimiter=',')
fsnv8_4 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston/FSVN_2_8.csv', delimiter=',')
fsnv8_14 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston/FSVN_2_1-8.csv', delimiter=',')


fsnv1 = fsnv[5:,:]
print(fsnv1)
# Out:
# [[ 9.05870331e-01  9.90129069e-01  1.72663799e-02 ...  6.90946488e-03
#   -1.65646661e+01 -1.65646673e+01]
#  [ 9.02200537e-01  9.90170236e-01  1.74380828e-02 ...  5.88052579e-03
#   -2.64300011e+01 -2.64300011e+01]
#  [ 9.23497645e-01  9.93401368e-01  3.05790623e-02 ...  3.46149855e-02
#   -4.89213542e+02 -4.89213427e+02]
#  ...
#  [ 9.16831161e-01  9.96210303e-01  9.42638603e-01 ...  3.91991534e-02
#   -3.06467052e-02 -3.06467052e-02]
#  [ 9.06834522e-01  9.92062516e-01  9.98357640e-01 ...  9.15811828e-02
#   -2.17061005e-01 -2.17061024e-01]
#  [ 9.29876486e-01  9.92794276e-01  8.59065318e-01 ...  4.97653049e-02
#   -4.72957955e+00 -4.72957955e+00]]

# %%
rnd = genfromtxt('/home/antoine/GPBT/FSN/random_Boston.csv', delimiter=',')
rnd=rnd[:,-3:-1]
a_rnd=max(rnd[1:,1])
i = np.argmax(rnd[1:,1])
b_rnd=rnd[i+1,0]
print(a_rnd)
print(b_rnd)
# Out:
# -0.0156787259905946
# -0.022631575079525217

# %%
fsnvc = genfromtxt('/home/antoine/GPBT/FSN/data_brut/trash/FSVN_cis1v2.csv', delimiter=',') #here is c=1

fsnvc1 = fsnvc[1:361,-5:]
fsnvc2 = fsnvc[362:722,-5:]
fsnvc3 = fsnvc[723:1083,-5:]
fsnvc4 = fsnvc[1084:1444,-5:]
fsnvc5 = fsnvc[1445:1805,-5:]
fsnvc6 = fsnvc[1806:2166,-5:]
fsnvc7 = fsnvc[2167:2527,-5:]
fsnvc8 = fsnvc[2528:2888,-5:]
fsnvc9 = fsnvc[2889:3249,-5:]
fsnvc10 = fsnvc[3250:3610,-5:]
iteration_corector(fsnvc1[:,-5],72)
iteration_corector(fsnvc2[:,-5],72)
iteration_corector(fsnvc3[:,-5],72)
iteration_corector(fsnvc4[:,-5],72)
iteration_corector(fsnvc5[:,-5],72)
iteration_corector(fsnvc6[:,-5],72)
iteration_corector(fsnvc7[:,-5],72)
iteration_corector(fsnvc8[:,-5],72)
iteration_corector(fsnvc9[:,-5],72)
iteration_corector(fsnvc10[:,-5],72)


#loss_test_iteration
fsnvc1 = -fsnvc1[np.argsort(fsnvc1[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc2 = -fsnvc2[np.argsort(fsnvc2[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc3 = -fsnvc3[np.argsort(fsnvc3[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc4 = -fsnvc4[np.argsort(fsnvc4[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc5 = -fsnvc5[np.argsort(fsnvc5[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc6 = -fsnvc6[np.argsort(fsnvc6[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc7 = -fsnvc7[np.argsort(fsnvc7[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc8 = -fsnvc8[np.argsort(fsnvc8[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc9 = -fsnvc9[np.argsort(fsnvc9[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc10 = -fsnvc10[np.argsort(fsnvc10[:,-5], axis = -1)][:,-2:]


maxof(fsnvc1[:,::-1])
maxof(fsnvc2[:,::-1])
maxof(fsnvc3[:,::-1])
maxof(fsnvc4[:,::-1])
maxof(fsnvc5[:,::-1])
maxof(fsnvc6[:,::-1])
maxof(fsnvc7[:,::-1])
maxof(fsnvc8[:,::-1])
maxof(fsnvc9[:,::-1])
maxof(fsnvc10[:,::-1])
# Out:
# array([[1.00000000e+02, 1.00000000e+02],
#        [5.15151702e+01, 6.21975720e+01],
#        [5.15151702e+01, 6.21975720e+01],
#        [5.05554917e+01, 5.80088561e+01],
#        [5.05554917e+01, 5.80088561e+01],
#        [5.05554917e+01, 5.80088561e+01],
#        [5.05554917e+01, 5.80088561e+01],
#        [5.05554917e+01, 5.80088561e+01],
#        [1.67126776e+01, 1.91641726e+01],
#        [1.67126776e+01, 1.91641726e+01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [9.89367691e-01, 8.71241401e-01],
#        [3.75069936e-01, 6.25706766e-01],
#        [3.75069936e-01, 6.25706766e-01],
# ...

# %%
fsnvc_ = genfromtxt('/home/antoine/GPBT/FSN/data_brut/trash/FSVN_cis1-2.csv', delimiter=',') #here is c=1

fsnvc_1 = fsnvc_[1:361,-5:]
fsnvc_2 = fsnvc_[362:722,-5:]
fsnvc_3 = fsnvc_[723:1083,-5:]
fsnvc_4 = fsnvc_[1084:1444,-5:]
fsnvc_5 = fsnvc_[1445:1805,-5:]
fsnvc_6 = fsnvc_[1806:2166,-5:]
fsnvc_7 = fsnvc_[2167:2527,-5:]
fsnvc_8 = fsnvc_[2528:2888,-5:]
fsnvc_9 = fsnvc_[2889:3249,-5:]
fsnvc_10 = fsnvc_[3250:3610,-5:]
iteration_corector(fsnvc_1[:,-5],72)
iteration_corector(fsnvc_2[:,-5],72)
iteration_corector(fsnvc_3[:,-5],72)
iteration_corector(fsnvc_4[:,-5],72)
iteration_corector(fsnvc_5[:,-5],72)
iteration_corector(fsnvc_6[:,-5],72)
iteration_corector(fsnvc_7[:,-5],72)
iteration_corector(fsnvc_8[:,-5],72)
iteration_corector(fsnvc_9[:,-5],72)
iteration_corector(fsnvc_10[:,-5],72)


#loss_test_iteration
fsnvc_1 = -fsnvc_1[np.argsort(fsnvc_1[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_2 = -fsnvc_2[np.argsort(fsnvc_2[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_3 = -fsnvc_3[np.argsort(fsnvc_3[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_4 = -fsnvc_4[np.argsort(fsnvc_4[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_5 = -fsnvc_5[np.argsort(fsnvc_5[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_6 = -fsnvc_6[np.argsort(fsnvc_6[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_7 = -fsnvc_7[np.argsort(fsnvc_7[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_8 = -fsnvc_8[np.argsort(fsnvc_8[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_9 = -fsnvc_9[np.argsort(fsnvc_9[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_10 = -fsnvc_10[np.argsort(fsnvc_10[:,-5], axis = -1,kind='stable')][:,-2:]


maxof(fsnvc_1[:,::-1])
maxof(fsnvc_2[:,::-1])
maxof(fsnvc_3[:,::-1])
maxof(fsnvc_4[:,::-1])
maxof(fsnvc_5[:,::-1])
maxof(fsnvc_6[:,::-1])
maxof(fsnvc_7[:,::-1])
maxof(fsnvc_8[:,::-1])
maxof(fsnvc_9[:,::-1])
maxof(fsnvc_10[:,::-1])
# Out:
# array([[1.00000000e+02, 1.00000000e+02],
#        [1.00000000e+02, 1.00000000e+02],
#        [1.00000000e+02, 1.00000000e+02],
#        [2.69779654e-01, 2.61840559e-01],
#        [2.69779654e-01, 2.61840559e-01],
#        [2.69779654e-01, 2.61840559e-01],
#        [2.69779654e-01, 2.61840559e-01],
#        [2.69779654e-01, 2.61840559e-01],
#        [2.69779654e-01, 2.61840559e-01],
#        [2.69779654e-01, 2.61840559e-01],
#        [1.40699835e-01, 1.84008972e-01],
#        [1.40699835e-01, 1.84008972e-01],
#        [1.40699835e-01, 1.84008972e-01],
#        [1.40699835e-01, 1.84008972e-01],
#        [1.40699835e-01, 1.84008972e-01],
#        [1.40699835e-01, 1.84008972e-01],
#        [1.40699835e-01, 1.84008972e-01],
#        [8.22353550e-02, 1.06728750e-01],
#        [8.22353550e-02, 1.06728750e-01],
#        [8.22353550e-02, 1.06728750e-01],
#        [8.22353550e-02, 1.06728750e-01],
#        [8.22353550e-02, 1.06728750e-01],
#        [8.22353550e-02, 1.06728750e-01],
# ...

# %%
fsnvc_nt = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston4/FSVN_cis1-2_notime.csv', delimiter=',') #here is c=1
fsnvc_nt1 = fsnvc_nt[1:361,-5:]
fsnvc_nt2 = fsnvc_nt[362:722,-5:]
fsnvc_nt3 = fsnvc_nt[723:1083,-5:]
fsnvc_nt4 = fsnvc_nt[1084:1444,-5:]
fsnvc_nt5 = fsnvc_nt[1445:1805,-5:]
fsnvc_nt6 = fsnvc_nt[1806:2166,-5:]
fsnvc_nt7 = fsnvc_nt[2167:2527,-5:]
fsnvc_nt8 = fsnvc_nt[2528:2888,-5:]
fsnvc_nt9 = fsnvc_nt[2889:3249,-5:]
fsnvc_nt10 = fsnvc_nt[3250:3610,-5:]
iteration_corector(fsnvc_nt1[:,-5],72)
iteration_corector(fsnvc_nt2[:,-5],72)
iteration_corector(fsnvc_nt3[:,-5],72)
iteration_corector(fsnvc_nt4[:,-5],72)
iteration_corector(fsnvc_nt5[:,-5],72)
iteration_corector(fsnvc_nt6[:,-5],72)
iteration_corector(fsnvc_nt7[:,-5],72)
iteration_corector(fsnvc_nt8[:,-5],72)
iteration_corector(fsnvc_nt9[:,-5],72)
iteration_corector(fsnvc_nt10[:,-5],72)


#loss_test_iteration
fsnvc_nt1 = -fsnvc_nt1[np.argsort(fsnvc_nt1[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt2 = -fsnvc_nt2[np.argsort(fsnvc_nt2[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt3 = -fsnvc_nt3[np.argsort(fsnvc_nt3[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt4 = -fsnvc_nt4[np.argsort(fsnvc_nt4[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt5 = -fsnvc_nt5[np.argsort(fsnvc_nt5[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt6 = -fsnvc_nt6[np.argsort(fsnvc_nt6[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt7 = -fsnvc_nt7[np.argsort(fsnvc_nt7[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt8 = -fsnvc_nt8[np.argsort(fsnvc_nt8[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt9 = -fsnvc_nt9[np.argsort(fsnvc_nt9[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_nt10 = -fsnvc_nt10[np.argsort(fsnvc_nt10[:,-5], axis = -1,kind='stable')][:,-2:]


maxof(fsnvc_nt1[:,::-1])
maxof(fsnvc_nt2[:,::-1])
maxof(fsnvc_nt3[:,::-1])
maxof(fsnvc_nt4[:,::-1])
maxof(fsnvc_nt5[:,::-1])
maxof(fsnvc_nt6[:,::-1])
maxof(fsnvc_nt7[:,::-1])
maxof(fsnvc_nt8[:,::-1])
maxof(fsnvc_nt9[:,::-1])
maxof(fsnvc_nt10[:,::-1])
[a3,b3,c3,d3] = getall(np.concatenate((fsnvc_nt1,fsnvc_nt2,fsnvc_nt3,fsnvc_nt4,fsnvc_nt5
                                       ,fsnvc_nt6,fsnvc_nt7,fsnvc_nt8,fsnvc_nt9,fsnvc_nt10),axis=1)[:360,::-1])

# %%
fsnvc_nt = genfromtxt('/home/antoine/GPBT/FSN/data_brut/trash/FSVN_cis1-2_notime_corect.csv', delimiter=',') #here is c=1
fsnvc_nt1 = fsnvc_nt[1:361,-5:]
fsnvc_nt2 = fsnvc_nt[362:722,-5:]
fsnvc_nt3 = fsnvc_nt[723:1083,-5:]
fsnvc_nt4 = fsnvc_nt[1084:1444,-5:]
fsnvc_nt5 = fsnvc_nt[1445:1805,-5:]
fsnvc_nt6 = fsnvc_nt[1806:2166,-5:]
fsnvc_nt7 = fsnvc_nt[2167:2527,-5:]
fsnvc_nt8 = fsnvc_nt[2528:2888,-5:]
fsnvc_nt9 = fsnvc_nt[2889:3249,-5:]
iteration_corector(fsnvc_nt1[:,-5],72)
iteration_corector(fsnvc_nt2[:,-5],72)
iteration_corector(fsnvc_nt3[:,-5],72)
iteration_corector(fsnvc_nt4[:,-5],72)
iteration_corector(fsnvc_nt5[:,-5],72)
iteration_corector(fsnvc_nt6[:,-5],72)
iteration_corector(fsnvc_nt7[:,-5],72)
iteration_corector(fsnvc_nt8[:,-5],72)
iteration_corector(fsnvc_nt9[:,-5],72)


#loss_test_iteration
fsnvc_ntc1 = -fsnvc_nt1[np.argsort(fsnvc_nt1[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc2 = -fsnvc_nt2[np.argsort(fsnvc_nt2[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc3 = -fsnvc_nt3[np.argsort(fsnvc_nt3[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc4 = -fsnvc_nt4[np.argsort(fsnvc_nt4[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc5 = -fsnvc_nt5[np.argsort(fsnvc_nt5[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc6 = -fsnvc_nt6[np.argsort(fsnvc_nt6[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc7 = -fsnvc_nt7[np.argsort(fsnvc_nt7[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc8 = -fsnvc_nt8[np.argsort(fsnvc_nt8[:,-5], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc9 = -fsnvc_nt9[np.argsort(fsnvc_nt9[:,-5], axis = -1,kind='stable')][:,-2:]


maxof(fsnvc_ntc1[:,::-1])
maxof(fsnvc_ntc2[:,::-1])
maxof(fsnvc_ntc3[:,::-1])
maxof(fsnvc_ntc4[:,::-1])
maxof(fsnvc_ntc5[:,::-1])
maxof(fsnvc_ntc6[:,::-1])
maxof(fsnvc_ntc7[:,::-1])
maxof(fsnvc_ntc8[:,::-1])
maxof(fsnvc_ntc9[:,::-1])
[a4,b4,c4,d4] = getall(np.concatenate((fsnvc_ntc1,fsnvc_ntc2,fsnvc_ntc3,fsnvc_ntc4,fsnvc_ntc5
                                       ,fsnvc_ntc6,fsnvc_ntc7,fsnvc_ntc8,fsnvc_ntc9),axis=1)[:360,::-1])

# %%
fsnvc_nt = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston4/FSVN_BOSTON_GP.csv', delimiter=',') #here is c=1
fsnvc_nt1 = fsnvc_nt[1:361,-5:]
fsnvc_nt2 = fsnvc_nt[362:722,-5:]
fsnvc_nt3 = fsnvc_nt[723:1083,-5:]
fsnvc_nt4 = fsnvc_nt[1084:1444,-5:]
fsnvc_nt5 = fsnvc_nt[1445:1805,-5:]

fsnvc_nt = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston4/GP_boston.csv', delimiter=',') #here is c=1
fsnvc_nt6 = fsnvc_nt[1:361,-5:]
fsnvc_nt7 = fsnvc_nt[362:722,-5:]
fsnvc_nt8 = fsnvc_nt[723:1083,-5:]
fsnvc_nt9 = fsnvc_nt[1084:1444,-5:]
fsnvc_nt10 = fsnvc_nt[1445:1805,-5:]
iteration_corector(fsnvc_nt1[:,0],72)
iteration_corector(fsnvc_nt2[:,-0],72)
iteration_corector(fsnvc_nt3[:,-0],72)
iteration_corector(fsnvc_nt4[:,-0],72)
iteration_corector(fsnvc_nt5[:,-0],72)
iteration_corector(fsnvc_nt6[:,-0],72)
iteration_corector(fsnvc_nt7[:,-0],72)
iteration_corector(fsnvc_nt8[:,-0],72)
iteration_corector(fsnvc_nt9[:,-0],72)
iteration_corector(fsnvc_nt10[:,-0],72)


#loss_test_iteration
fsnvc_ntc1 = -fsnvc_nt1[np.argsort(fsnvc_nt1[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc2 = -fsnvc_nt2[np.argsort(fsnvc_nt2[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc3 = -fsnvc_nt3[np.argsort(fsnvc_nt3[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc4 = -fsnvc_nt4[np.argsort(fsnvc_nt4[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc5 = -fsnvc_nt5[np.argsort(fsnvc_nt5[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc6 = -fsnvc_nt6[np.argsort(fsnvc_nt6[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc7 = -fsnvc_nt7[np.argsort(fsnvc_nt7[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc8 = -fsnvc_nt8[np.argsort(fsnvc_nt8[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc9 = -fsnvc_nt9[np.argsort(fsnvc_nt9[:,-0], axis = -1,kind='stable')][:,-2:]
fsnvc_ntc10 = -fsnvc_nt10[np.argsort(fsnvc_nt10[:,-0], axis = -1,kind='stable')][:,-2:]


maxof(fsnvc_ntc1[:,::-1])
maxof(fsnvc_ntc2[:,::-1])
maxof(fsnvc_ntc3[:,::-1])
maxof(fsnvc_ntc4[:,::-1])
maxof(fsnvc_ntc5[:,::-1])
maxof(fsnvc_ntc6[:,::-1])
maxof(fsnvc_ntc7[:,::-1])
maxof(fsnvc_ntc8[:,::-1])
maxof(fsnvc_ntc9[:,::-1])
maxof(fsnvc_ntc10[:,::-1])
[a4,b4,c4,d4] = getall(np.concatenate((fsnvc_ntc1,fsnvc_ntc2,fsnvc_ntc3,fsnvc_ntc4,fsnvc_ntc5
                                         ,fsnvc_ntc6,fsnvc_ntc7,fsnvc_ntc8,fsnvc_ntc9,fsnvc_ntc10),axis=1)[:360,::-1])
t= np.arange(0,360)*400/360
np.savetxt('FSVN_Boston_GM_time_c=1_2.csv', np.array([t,a4,b4,c4,d4]).T, delimiter=',')

# %%
plt.plot(a4)

# %%
plt.plot(fsnvc_6[:,0])
plt.plot(fsnvc_7[:,0])
plt.plot(fsnvc_8[:,0])
plt.plot(fsnvc_9[:,0])
plt.plot(fsnvc_10[:,0])

axes = plt.gca()
axes.set_ylim(.01,.1)
axes.set_yscale('log')
[a1,b1,c1,d1] = getall(np.concatenate((fsnvc1,fsnvc2,fsnvc3,fsnvc4,fsnvc5
                                       ,fsnvc6,fsnvc7,fsnvc8,fsnvc9,fsnvc10),axis=1)[:360,::-1])
[a2,b2,c2,d2] = getall(np.concatenate((fsnvc_1,fsnvc_2,fsnvc_3,fsnvc_4,fsnvc_5
                                       ,fsnvc_6,fsnvc_7,fsnvc_8,fsnvc_9,fsnvc_10),axis=1)[:360,::-1])
#[a3,b3,c3,d3] = getall(np.concatenate((fsnvc_nt1,fsnvc_nt2,fsnvc_nt3,fsnvc_nt4,fsnvc_nt5
  #                                     ,fsnvc_nt6,fsnvc_nt7,fsnvc_nt8,fsnvc_nt9,fsnvc_nt10),axis=1)[:360,::-1])

# %%
plt.plot(b4,'k')
plt.plot(b3)
axes = plt.gca()
axes.set_ylim(0.0001,.2)
axes.set_ylabel('error')

axes.set_xlabel('execution time (s)')
axes.set_title('Comparison on val Boston with 10 experiment')
#plt.title(r'\underline{Validation loss}:')
axes.set_yscale('log')

# %%
t= np.arange(0,360)*375/360
np.savetxt('our_idea-c_is1.csv', np.array([t,a1,b1,c1,d1]).T, delimiter=' ')
np.savetxt('our_idea-c_is1-2.csv', np.array([t,a2,b2,c2,d2]).T, delimiter=' ')
np.savetxt('our_idea-c_is1-2_noTimeTPE.csv', np.array([t,a3,b3,c3,d3]).T, delimiter=' ')

# %%
def iteration_corector(liste, num_config):
    for i in range(len(liste[:])):
        liste[i] = math.floor(i/num_config)

# %%
hyper1 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt1.csv', delimiter=',')
hyper2 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt2.csv', delimiter=',')
hyper3 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt3.csv', delimiter=',')
hyper4 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt4.csv', delimiter=',')
hyper5 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt5.csv', delimiter=',')
hyper6 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt6.csv', delimiter=',')
hyper7 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt7.csv', delimiter=',')
hyper8 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt8.csv', delimiter=',')
hyper9 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt9.csv', delimiter=',')
hyper10 = genfromtxt('/home/antoine/GPBT/FSN/data_brut/Boston3/Boston_HyperOpt0.csv', delimiter=',')

hyper1_ = fonc(hyper1)
hyper2_ = fonc(hyper2)
hyper3_ = fonc(hyper3)
hyper4_ = fonc(hyper4)
hyper5_ = fonc(hyper5)
hyper6_ = fonc(hyper6)
hyper7_ = fonc(hyper7)
hyper8_ = fonc(hyper8)
hyper9_ = fonc(hyper9)
hyper10_ = fonc(hyper10)


#loss_test_iteration
hyper1 = hyper1_#[np.argsort(hyper1[:,5][~np.isnan(hyper1[:,5])], axis = -1,kind='stable')][:,0:2]
hyper2 = hyper2_#[np.argsort(hyper2[:,5][~np.isnan(hyper2[:,5])], axis = -1,kind='stable')][:,0:2]
hyper3 = hyper3_#[np.argsort(hyper3[:,5][~np.isnan(hyper3[:,5])], axis = -1,kind='stable')][:,0:2]
hyper4 = hyper4_#[np.argsort(hyper4[:,5][~np.isnan(hyper4[:,5])], axis = -1,kind='stable')][:,0:2]
hyper5 = hyper5_#[np.argsort(hyper5[:,5][~np.isnan(hyper5[:,5])], axis = -1,kind='stable')][:,0:2]
hyper6 = hyper6_#[np.argsort(hyper6[:,5][~np.isnan(hyper6[:,5])], axis = -1,kind='stable')][:,0:2]
hyper7 = hyper7_#[np.argsort(hyper7[:,5][~np.isnan(hyper7[:,5])], axis = -1,kind='stable')][:,0:2]
hyper8 = hyper8_#[np.argsort(hyper8[:,5][~np.isnan(hyper8[:,5])], axis = -1,kind='stable')][:,0:2]
hyper9 = hyper9_#[np.argsort(hyper9[:,5][~np.isnan(hyper9[:,5])], axis = -1,kind='stable')][:,0:2]
hyper10 = hyper10_#[np.argsort(hyper10[:,5][~np.isnan(hyper10[:,5])], axis = -1,kind='stable')][:,0:2]


fsnv1 = fsnv[1:361,-5:]
fsnv2 = fsnv[361:721,-5:]
fsnv3 = fsnv[721:1081,-5:]
fsnv4 = fsnv[1081:1441,-5:]
fsnv5 = fsnv[1441:1801,-5:]
fsnv6 = fsnv[1801:2161,-5:]
fsnv7 = fsnv[2162:2522,-5:]
fsnv8 = fsnv[2523:2883,-5:]
fsnv9 = fsnv[2884:3244,-5:]
fsnv10 = fsnv[3245:3605,-5:]
iteration_corector(fsnv1[:,-5],72)
iteration_corector(fsnv2[:,-5],72)
iteration_corector(fsnv3[:,-5],72)
iteration_corector(fsnv4[:,-5],72)
iteration_corector(fsnv5[:,-5],72)
iteration_corector(fsnv6[:,-5],72)
iteration_corector(fsnv7[:,-5],72)
iteration_corector(fsnv8[:,-5],72)
iteration_corector(fsnv9[:,-5],72)
iteration_corector(fsnv10[:,-5],72)


#loss_test_iteration
fsnv1 = -fsnv1[np.argsort(fsnv1[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv2 = -fsnv2[np.argsort(fsnv2[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv3 = -fsnv3[np.argsort(fsnv3[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv4 = -fsnv4[np.argsort(fsnv4[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv5 = -fsnv5[np.argsort(fsnv5[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv6 = -fsnv6[np.argsort(fsnv6[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv7 = -fsnv7[np.argsort(fsnv7[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8 = -fsnv8[np.argsort(fsnv8[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv9 = -fsnv9[np.argsort(fsnv9[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv10 = -fsnv10[np.argsort(fsnv10[:,-5], axis = -1,kind='stable')][:,-2:]

fsnv_41 = fsnv_4[1:361,-5:]
fsnv_42 = fsnv_4[361:721,-5:]
fsnv_43 = fsnv_4[722:1082,-5:]
fsnv_44 = fsnv_4[1083:1443,-5:]
fsnv_45 = fsnv_4[1444:1804,-5:]
fsnv_46 = fsnv_4[1805:2165,-5:]
fsnv_47 = fsnv_4[2166:2526,-5:]
fsnv_48 = fsnv_4[2527:2887,-5:]
fsnv_49 = fsnv_4[2888:3248,-5:]
fsnv_410 = fsnv_4[3249:3609,-5:]
iteration_corector(fsnv_41[:,-5],72)
iteration_corector(fsnv_42[:,-5],72)
iteration_corector(fsnv_43[:,-5],72)
iteration_corector(fsnv_44[:,-5],72)
iteration_corector(fsnv_45[:,-5],72)
iteration_corector(fsnv_46[:,-5],72)
iteration_corector(fsnv_47[:,-5],72)
iteration_corector(fsnv_48[:,-5],72)
iteration_corector(fsnv_49[:,-5],72)
iteration_corector(fsnv_410[:,-5],72)


#loss_test_iteration
fsnv_41 = -fsnv_41[np.argsort(fsnv_41[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_42 = -fsnv_42[np.argsort(fsnv_42[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_43 = -fsnv_43[np.argsort(fsnv_43[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_44 = -fsnv_44[np.argsort(fsnv_44[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_45 = -fsnv_45[np.argsort(fsnv_45[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_46 = -fsnv_46[np.argsort(fsnv_46[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_47 = -fsnv_47[np.argsort(fsnv_47[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_48 = -fsnv_48[np.argsort(fsnv_48[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_49 = -fsnv_49[np.argsort(fsnv_49[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_410 = -fsnv_410[np.argsort(fsnv_410[:,-5], axis = -1,kind='stable')][:,-2:]

fsnv_141 = fsnv_14[1:361,-5:]
fsnv_142 = fsnv_14[361:721,-5:]
fsnv_143 = fsnv_14[722:1082,-5:]
fsnv_144 = fsnv_14[1083:1443,-5:]
fsnv_145 = fsnv_14[1444:1804,-5:]
fsnv_146 = fsnv_14[1805:2165,-5:]
fsnv_147 = fsnv_14[2166:2526,-5:]
fsnv_148 = fsnv_14[2527:2887,-5:]
fsnv_149 = fsnv_14[2888:3248,-5:]
fsnv_1410 = fsnv_14[3249:3609,-5:]
iteration_corector(fsnv_141[:,-5],72)
iteration_corector(fsnv_142[:,-5],72)
iteration_corector(fsnv_143[:,-5],72)
iteration_corector(fsnv_144[:,-5],72)
iteration_corector(fsnv_145[:,-5],72)
iteration_corector(fsnv_146[:,-5],72)
iteration_corector(fsnv_147[:,-5],72)
iteration_corector(fsnv_148[:,-5],72)
iteration_corector(fsnv_149[:,-5],72)
iteration_corector(fsnv_1410[:,-5],72)


#loss_test_iteration
fsnv_141 = -fsnv_141[np.argsort(fsnv_141[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_142 = -fsnv_142[np.argsort(fsnv_142[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_143 = -fsnv_143[np.argsort(fsnv_143[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_144 = -fsnv_144[np.argsort(fsnv_144[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_145 = -fsnv_145[np.argsort(fsnv_145[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_146 = -fsnv_146[np.argsort(fsnv_146[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_147 = -fsnv_147[np.argsort(fsnv_147[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_148 = -fsnv_148[np.argsort(fsnv_148[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_149 = -fsnv_149[np.argsort(fsnv_149[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv_1410 = -fsnv_1410[np.argsort(fsnv_1410[:,-5], axis = -1,kind='stable')][:,-2:]


fsnv8_41 = fsnv8_4[1:361,-5:]
fsnv8_42 = fsnv8_4[361:721,-5:]
fsnv8_43 = fsnv8_4[721:1081,-5:]
fsnv8_44 = fsnv8_4[1081:1441,-5:]
fsnv8_45 = fsnv8_4[1441:1801,-5:]
fsnv8_46 = fsnv8_4[1801:2161,-5:]
fsnv8_47 = fsnv8_4[2161:2521,-5:]
fsnv8_48 = fsnv8_4[2522:2882,-5:]
fsnv8_49 = fsnv8_4[2883:3243,-5:]
fsnv8_410 = fsnv8_4[3244:3604,-5:]
iteration_corector(fsnv8_41[:,-5],72)
iteration_corector(fsnv8_42[:,-5],72)
iteration_corector(fsnv8_43[:,-5],72)
iteration_corector(fsnv8_44[:,-5],72)
iteration_corector(fsnv8_45[:,-5],72)
iteration_corector(fsnv8_46[:,-5],72)
iteration_corector(fsnv8_47[:,-5],72)
iteration_corector(fsnv8_48[:,-5],72)
iteration_corector(fsnv8_49[:,-5],72)
iteration_corector(fsnv8_410[:,-5],72)


#loss_test_iteration
fsnv8_41 = -fsnv8_41[np.argsort(fsnv8_41[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_42 = -fsnv8_42[np.argsort(fsnv8_42[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_43 = -fsnv8_43[np.argsort(fsnv8_43[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_44 = -fsnv8_44[np.argsort(fsnv8_44[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_45 = -fsnv8_45[np.argsort(fsnv8_45[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_46 = -fsnv8_46[np.argsort(fsnv8_46[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_47 = -fsnv8_47[np.argsort(fsnv8_47[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_48 = -fsnv8_48[np.argsort(fsnv8_48[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_49 = -fsnv8_49[np.argsort(fsnv8_49[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_410 = -fsnv8_410[np.argsort(fsnv8_410[:,-5], axis = -1,kind='stable')][:,-2:]

fsnv8_141 = fsnv8_14[1:361,-5:]
fsnv8_142 = fsnv8_14[361:721,-5:]
fsnv8_143 = fsnv8_14[721:1081,-5:]
fsnv8_144 = fsnv8_14[1083:1443,-5:]
fsnv8_145 = fsnv8_14[1444:1804,-5:]
fsnv8_146 = fsnv8_14[1805:2165,-5:]
fsnv8_147 = fsnv8_14[2166:2526,-5:]
fsnv8_148 = fsnv8_14[2527:2887,-5:]
fsnv8_149 = fsnv8_14[2888:3248,-5:]
fsnv8_1410 = fsnv8_14[3249:3609,-5:]
iteration_corector(fsnv8_141[:,-5],72)
iteration_corector(fsnv8_142[:,-5],72)
iteration_corector(fsnv8_143[:,-5],72)
iteration_corector(fsnv8_144[:,-5],72)
iteration_corector(fsnv8_145[:,-5],72)
iteration_corector(fsnv8_146[:,-5],72)
iteration_corector(fsnv8_147[:,-5],72)
iteration_corector(fsnv8_148[:,-5],72)
iteration_corector(fsnv8_149[:,-5],72)
iteration_corector(fsnv8_1410[:,-5],72)


#loss_test_iteration
fsnv8_141 = -fsnv8_141[np.argsort(fsnv8_141[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_142 = -fsnv8_142[np.argsort(fsnv8_142[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_143 = -fsnv8_143[np.argsort(fsnv8_143[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_144 = -fsnv8_144[np.argsort(fsnv8_144[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_145 = -fsnv8_145[np.argsort(fsnv8_145[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_146 = -fsnv8_146[np.argsort(fsnv8_146[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_147 = -fsnv8_147[np.argsort(fsnv8_147[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_148 = -fsnv8_148[np.argsort(fsnv8_148[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_149 = -fsnv8_149[np.argsort(fsnv8_149[:,-5], axis = -1,kind='stable')][:,-2:]
fsnv8_1410 = -fsnv8_1410[np.argsort(fsnv8_1410[:,-5], axis = -1,kind='stable')][:,-2:]

# %%
def maxof(a):
    ma = 100;
    ta = 100;
    for i in range(360):
        if(a.shape[0]<=i):
            a=np.concatenate((a,(np.array([np.array([ma,ta])]))))
            print(a.shape)
        else:
            if(ma>a[i,0]):
                ta = a[i,1]
            ma = min(ma,a[i,0]) 
            a[i,0] = ma
            a[i,1] = ta
    return a[:360]

# %%
maxof(hyper1[:,::-1])
maxof(hyper2[:,::-1])
maxof(hyper3[:,::-1])
maxof(hyper4[:,::-1])
maxof(hyper5[:,::-1])
maxof(hyper6[:,::-1])
maxof(hyper7[:,::-1])
maxof(hyper8[:,::-1])
maxof(hyper9[:,::-1])
maxof(hyper10[:,::-1])

maxof(fsnv1)
maxof(fsnv2)
maxof(fsnv3)
maxof(fsnv4)
maxof(fsnv5)
maxof(fsnv6)
maxof(fsnv7)
maxof(fsnv8)
maxof(fsnv9)
maxof(fsnv10)

maxof(fsnv_41)
maxof(fsnv_42)
maxof(fsnv_43)
maxof(fsnv_44)
maxof(fsnv_45)
maxof(fsnv_46)
maxof(fsnv_47)
maxof(fsnv_48)
maxof(fsnv_49)
maxof(fsnv_410)

maxof(fsnv_141)
maxof(fsnv_142)
maxof(fsnv_143)
maxof(fsnv_144)
maxof(fsnv_145)
maxof(fsnv_146)
maxof(fsnv_147)
maxof(fsnv_148)
maxof(fsnv_149)
maxof(fsnv_1410)
maxof(fsnv8_41)
maxof(fsnv8_42)
maxof(fsnv8_43)
maxof(fsnv8_44)
maxof(fsnv8_45)
maxof(fsnv8_46)
maxof(fsnv8_47)
maxof(fsnv8_48)
maxof(fsnv8_49)
maxof(fsnv8_410)

maxof(fsnv8_141)
maxof(fsnv8_142)
maxof(fsnv8_143)
maxof(fsnv8_144)
maxof(fsnv8_145)
maxof(fsnv8_146)
maxof(fsnv8_147)
maxof(fsnv8_148)
maxof(fsnv8_149)
maxof(fsnv8_1410)
# Out:
# array([[1.00000000e+02, 1.00000000e+02],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [3.89989606e+00, 3.89989606e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
#        [1.25815074e+00, 1.25815059e+00],
# ...

# %%
print(hyper1)
# Out:
# [[-0.99175129 -0.79842107]
#  [-0.99175129 -0.79842107]
#  [-0.99175129 -0.79842107]
#  [-0.99175129 -0.79842107]
#  [-0.99175129 -0.79842107]
#  [-0.99280598 -0.11866908]
#  [-0.99280598 -0.11866908]
#  [-0.99280598 -0.11866908]
#  [-0.99280598 -0.11866908]
#  [-0.99280598 -0.11866908]
#  [-0.99863503 -0.89823379]
#  [-0.99863503 -0.89823379]
#  [-0.99863503 -0.89823379]
#  [-0.99863503 -0.89823379]
#  [-0.99863503 -0.89823379]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
#  [-0.99921996 -0.82513908]
# ...

# %%
t= np.arange(0,360)*375/360

plt.plot(t,np.concatenate((hyper1,hyper2,hyper3,hyper4,hyper5),axis=1)[:,1::2])


axes = plt.gca()
axes.set_ylim(0.01,2)
axes.set_ylabel('error')

axes.set_xlabel('execution time (s)')
axes.set_title('Comparison on val Boston with 10 experiment')
#plt.title(r'\underline{Validation loss}:')
axes.set_yscale('log')

# %%
from scipy.signal import savgol_filter

def getall(a):
    f = [b for b in a[:,1::2].mean(1)]
    g = [b for b in a[:,0::2].mean(1)]
    def h(x):
        return savgol_filter(np.ravel(x),23, 1)
    return (h(f), h(a[:,1::2].std(1)/2),
            h(g), h(a[:,0::2].std(1)/2))

# %%
[it,jt,kt,lt] = getall(np.concatenate((pbt1,pbt2,pbt3,pbt4,pbt5,pbt6,pbt7,pbt8,pbt9,pbt10),axis=1)[:352,])

# %%
[m,n,o,p] = getall(np.concatenate((_b1,_b2,_b3,_b4,_b5,_b6,_b7,_b8,_b9,_b10),axis=1)[:224,::1])

[a,b,c,d] = getall(np.concatenate((fsnv1,fsnv2,fsnv3,fsnv4,fsnv5,fsnv6,fsnv7,fsnv8,fsnv9,fsnv10),axis=1))
[a4,b4,c4,d4] = getall(np.concatenate((fsnv_41,fsnv_42,fsnv_43,fsnv_44,fsnv_45,fsnv_46,fsnv_47,fsnv_48,fsnv_49,fsnv_410),axis=1))
[a14,b14,c14,d14] = getall(np.concatenate((fsnv_141,fsnv_142,fsnv_143,fsnv_144,fsnv_145,fsnv_146,fsnv_147,fsnv_148,fsnv_149,fsnv_1410),axis=1))

[a8,b8,c8,d8] = getall(np.concatenate((fsnv8_41,fsnv8_42,fsnv8_43,fsnv8_44,fsnv8_45,fsnv8_46,fsnv8_47,fsnv8_48,fsnv8_49,fsnv8_410),axis=1))
[a18,b18,c18,d18] = getall(np.concatenate((fsnv8_141,fsnv8_142,fsnv8_143,fsnv8_144,fsnv8_145,fsnv8_146,fsnv8_147,fsnv8_148,fsnv8_149,fsnv8_1410),axis=1))

[e,f,g,h] = getall(np.concatenate((hyper1,hyper2,hyper3,hyper4,hyper5,hyper6,hyper7,hyper8,hyper9,hyper10
                                  ),axis=1)[:,::-1])

[i,j,k,l] = getall(np.concatenate((pb1,pb2,pb3,pb4,pb5,pb6,pb7,pb8,pb9,pb10),axis=1))

# %%
t= np.arange(0,360)*369/360
np.savetxt('hyperopt_boston.csv', np.array([t,e,f,g,h]).T, delimiter=' ')
t= np.arange(0,352)*387/352
np.savetxt('PBT_boston.csv', np.array([t,it,jt,kt,lt]).T, delimiter=' ')
t= np.arange(0,224)*269/224
np.savetxt('BOHB_boston.csv', np.array([t,m,n,o,p]).T, delimiter=',')
t= np.arange(0,360)*411/360
np.savetxt('PB2_boston.csv', np.array([t,i,j,k,l]).T, delimiter=',')

t= np.arange(0,360)*375/360
np.savetxt('FSVN_c=2.csv', np.array([t,a,b,c,d]).T, delimiter=',')
np.savetxt('FSVN_c=4.csv', np.array([t,a4,b4,c4,d4]).T, delimiter=',')
np.savetxt('FSVN_c=1-4.csv', np.array([t,a14,b14,c14,d14]).T, delimiter=',')
np.savetxt('FSVN_c=8.csv', np.array([t,a8,b8,c8,d8]).T, delimiter=',')
np.savetxt('FSVN_c=1-8.csv', np.array([t,a18,b18,c18,d18]).T, delimiter=',')

# %%
cma = genfromtxt('/home/antoine/Téléchargements/FSVN_CMA_Boston_final.csv', delimiter=',')
temp = []
for i in range(10):
    temp.append(cma[72*5*i+i+1:72*5*(i+1)+i+1,-2:])
    
cma1 = maxof( temp[0])
cma2 = maxof( temp[1])
cma3 = maxof( temp[2])
cma4 = maxof( temp[3])
cma5 = maxof( temp[4])
cma6 = maxof( temp[5])
cma7 = maxof( temp[6])
cma8 = maxof( temp[7])
cma9 = maxof( temp[8])
cma10 = maxof( temp[9])
[xa,xb,xc,xd] = getall(np.concatenate((cma1,cma2,cma3,cma4,cma5,cma6,cma7,cma8,cma9,cma10),axis=1))
axes = plt.gca()
plt.plot(xa,c='b')
axes.set_ylim(0.013,.2)

plt.plot(xc,c='k')

# %%
b_rnd
# Out:
# -0.015788273484099145

# %%
#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')




t= np.arange(0,224)*269/224
plt.plot(t,o,color=(0,1,1),label = "BOHB")
plt.fill_between(t, o-p/2,  o+p/2, alpha = 0.2,color=(0,1,1))


t= np.arange(0,360)*369/360
ax2.plot(t,e,color=(0,1,0),label = "hyper")
ax2.fill_between(t, e-f,  e+f, alpha = 0.2,color=(0,1,0))

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c2,color=(0,0,1),label = "color=1/2_tpe_time")
plt.fill_between(t, c2-d2,  c2+d2, alpha = 0.2,color=(0,0,1))

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')

plt.plot(t,c3,color=(1,.8,0),label = "color=1/2_tpe")
plt.fill_between(t, c3-d3,  c3+d3, alpha = 0.2,color=(1,.8,0))


plt.plot(t,xc,color=(0,0,0),label = "color=1/2_cma")
plt.fill_between(t, xc-xd,  xc+xd, alpha = 0.2,color=(0,0,0))



t= np.arange(0,360)*400/360
#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c4,color=(.45,.26,0),label = "color=1/2_GP_time")
plt.fill_between(t, c4-d4,  c4+d4, alpha = 0.4,color=(.45,.26,0))



t= np.arange(0,360)*411/360

plt.plot(t,k,color=(1,0,0),label = "PB2")
plt.fill_between(t, k-l,  k+l, alpha = 0.2,color=(1,0,0))

t= np.arange(0,352)*387/352
plt.plot(t,kt,color=(1,0,1),label = "PBT")
plt.fill_between(t, kt-lt,  kt+lt, alpha = 0.2,color=(1,0,1))



axes = plt.gca()
axes.set_ylim(0.013,.2)
axes.set_ylabel('MSE error',fontsize=16)
import matplotlib.ticker as plticker

axes.set_xlabel('execution time (s)',fontsize=16)
axes.set_yscale('log')

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

#axes.set_title('Comparison on val Boston with 10 experiment')
#plt.title(r'\underline{Validation loss}:')
#plt.legend()
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.tight_layout()
plt.savefig('Boston_val.pdf',format='pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-5981ef2feba1> in <module>
#      12
#      13 t= np.arange(0,360)*369/360
# ---> 14 ax2.plot(t,e,color=(0,1,0),label = "hyper")
#      15 ax2.fill_between(t, e-f,  e+f, alpha = 0.2,color=(0,1,0))
#      16
#
# NameError: name 'ax2' is not defined

# %%
#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')

ax2 = plt
t= np.arange(0,224)*269/224
ax2.plot(t,m,color=(0,1,1),label = "BOHB")
ax2.fill_between(t, m-n,  m+n, alpha = 0.2,color=(0,1,1))


t= np.arange(0,360)*369/360
plt.plot(t,g,color=(0,1,0),label = "hyper")
plt.fill_between(t, g-h/2,  g+h/2, alpha = 0.2,color=(0,1,0))

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax2.plot(t,a2,color=(0,0,1),label = "color=1/2")
ax2.fill_between(t, a2-b2,  a2+b2, alpha = 0.2,color=(0,0,1))

#plt.fill_between(t, c4-d4,  c4+d4, alpha = 0.2,color='y')

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax2.plot(t,a3,color=(1,.8,0),label = "color=1/2_no time")
ax2.fill_between(t, a3-b3,  a3+b3, alpha = 0.2,color=(1,.8,0))

ax2.plot(t,xa,color=(0,0,0),label = "color=1/2_cma")
ax2.fill_between(t, xa-xb,  xa+xb, alpha = 0.2,color=(0,0,0))

t= np.arange(0,360)*400/360
#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax2.plot(t,a4,color=(.45,.26,0),label = "color=1/2_GP_time")
ax2.fill_between(t, a4-b4,  a4+b4, alpha = 0.2,color=(.45,.26,0))



t= np.arange(0,360)*411/360

ax2.plot(t,i,color=(1,0,0),label = "PB2")
ax2.fill_between(t, i-j,  i+j, alpha = 0.2,color=(1,0,0))

t= np.arange(0,352)*387/352
ax2.plot(t,it,color=(1,0,1),label = "PBT")
ax2.fill_between(t, it-jt,  it+jt, alpha = 0.2,color=(1,0,1))



axes = plt.gca()
axes.set_ylim(0.013,.2)
axes.set_xlim(0,420)

axes.set_ylabel('MSE error',fontsize=18)

axes.set_yscale('log')

axes.set_xlabel('execution time (s)',fontsize=18)
ax1.set_xticks([0,200, 400])
ax1.set_xticklabels([0,200, 400],fontsize=18)
ax1.set_yticks([.02,.04,.08,0.16])
ax1.set_yticklabels([.02,.04,.08,0.16],fontsize=18)

fig.tight_layout()
plt.subplots_adjust(wspace=0,left = .06, right = .999,bottom=0.15,top = .95)


fig.set_size_inches(16, 4)


plt.savefig('Boston_all.pdf')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)



#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')
t= np.arange(0,420)

ax1.plot(t,-a_rnd*np.ones(420),color=(0,.5,0),label = "random",linestyle='dashed',linewidth=1)



t= np.arange(0,224)*269/224
ax1.plot(t,o,color=(0,1,1),label = "BOHB")
ax1.fill_between(t, o-p/2,  o+p/2, alpha = 0.2,color=(0,1,1))


t= np.arange(0,360)*369/360
ax1.plot(t,e,color=(0,1,0),label = "hyper")
ax1.fill_between(t, e-f,  e+f, alpha = 0.2,color=(0,1,0))

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax1.plot(t,c2,color=(0,0,1),label = "color=1/2_tpe_time")
ax1.fill_between(t, c2-d2,  c2+d2, alpha = 0.2,color=(0,0,1))

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')

ax1.plot(t,c3,color=(1,.8,0),label = "color=1/2_tpe")
ax1.fill_between(t, c3-d3,  c3+d3, alpha = 0.2,color=(1,.8,0))


ax1.plot(t,xc,color=(0,0,0),label = "color=1/2_cma")
ax1.fill_between(t, xc-xd,  xc+xd, alpha = 0.2,color=(0,0,0))



t= np.arange(0,360)*400/360
#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax1.plot(t,c4,color=(.45,.26,0),label = "color=1/2_GP_time")
ax1.fill_between(t, c4-d4,  c4+d4, alpha = 0.4,color=(.45,.26,0))



t= np.arange(0,360)*411/360

ax1.plot(t,k,color=(1,0,0),label = "PB2")
ax1.fill_between(t, k-l,  k+l, alpha = 0.2,color=(1,0,0))

t= np.arange(0,352)*387/352
ax1.plot(t,kt,color=(1,0,1),label = "PBT")
ax1.fill_between(t, kt-lt,  kt+lt, alpha = 0.2,color=(1,0,1))



axes = ax1
axes.set_xlim(0,420)
axes.set_ylim(0.013,.2)
axes.set_ylabel('MSE error',fontsize=18)
import matplotlib.ticker as plticker

axes.set_xlabel('execution time (s)',fontsize=18)
axes.set_yscale('log')

#plt.xticks(fontsize=18)
#plt.yticks(fontsize=18)



#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')

t= np.arange(0,420)

ax2.plot(t,-b_rnd*np.ones(420),color=(0,.5,0),label = "random",linestyle='dashed',linewidth=1)


t= np.arange(0,224)*269/224
ax2.plot(t,m,color=(0,1,1),label = "BOHB")
ax2.fill_between(t, m-n,  m+n, alpha = 0.2,color=(0,1,1))


t= np.arange(0,360)*369/360
plt.plot(t,g,color=(0,1,0),label = "hyper")
plt.fill_between(t, g-h/2,  g+h/2, alpha = 0.2,color=(0,1,0))

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax2.plot(t,a2,color=(0,0,1),label = "color=1/2")
ax2.fill_between(t, a2-b2,  a2+b2, alpha = 0.2,color=(0,0,1))

#plt.fill_between(t, c4-d4,  c4+d4, alpha = 0.2,color='y')

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax2.plot(t,a3,color=(1,.8,0),label = "color=1/2_no time")
ax2.fill_between(t, a3-b3,  a3+b3, alpha = 0.2,color=(1,.8,0))

ax2.plot(t,xa,color=(0,0,0),label = "color=1/2_cma")
ax2.fill_between(t, xa-xb,  xa+xb, alpha = 0.2,color=(0,0,0))

t= np.arange(0,360)*400/360
#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
ax2.plot(t,a4,color=(.45,.26,0),label = "color=1/2_GP_time")
ax2.fill_between(t, a4-b4,  a4+b4, alpha = 0.2,color=(.45,.26,0))



t= np.arange(0,360)*411/360

ax2.plot(t,i,color=(1,0,0),label = "PB2")
ax2.fill_between(t, i-j,  i+j, alpha = 0.2,color=(1,0,0))

t= np.arange(0,352)*387/352
ax2.plot(t,it,color=(1,0,1),label = "PBT")
ax2.fill_between(t, it-jt,  it+jt, alpha = 0.2,color=(1,0,1))



axes = plt.gca()
axes.set_ylim(0.013,.2)
axes.set_xlim(0,420)


axes.set_yscale('log')

axes.set_xlabel('execution time (s)',fontsize=18)
ax1.set_xticks([0,200, 400])
ax2.set_xticks([0,200, 400])
ax1.set_xticklabels([0,200, 400],fontsize=18)
ax2.set_xticklabels([0,200, 400],fontsize=18)
ax1.set_yticks([.02,.04,.08,0.16])
ax1.set_yticklabels([.02,.04,.08,0.16],fontsize=18)
ax2.set_yticks([])

fig.tight_layout()
plt.subplots_adjust(wspace=0,left = .06, right = .999,bottom=0.15,top = .95)


fig.set_size_inches(16, 4)


plt.savefig('Boston_all.pdf')
plt.show()

# %%
#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')




t= np.arange(0,224)*269/224
plt.plot(t,m,color=(0,1,1),label = "BOHB")
plt.fill_between(t, m-n,  m+n, alpha = 0.2,color=(0,1,1))


t= np.arange(0,360)*369/360
plt.plot(t,e,color=(0,1,0),label = "hyper")
plt.fill_between(t, e-f,  e+f, alpha = 0.2,color=(0,1,0))


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a2,color=(0,0,1),label = "color=1/2")
plt.fill_between(t, a2-b2,  a2+b2, alpha = 0.2,color=(0,0,1))

#plt.fill_between(t, c4-d4,  c4+d4, alpha = 0.2,color='y')

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a3,color=(1,.8,0),label = "color=1/2_no time")
plt.fill_between(t, a3-b3,  a3+b3, alpha = 0.2,color=(1,.8,0))

plt.plot(t,xa,color=(0,0,0),label = "color=1/2_cma")
plt.fill_between(t, xa-xb,  xa+xb, alpha = 0.2,color=(0,0,0))

t= np.arange(0,360)*400/360
#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a4,color=(.45,.26,0),label = "color=1/2_GP_time")
plt.fill_between(t, a4-b4,  a4+b4, alpha = 0.2,color=(.45,.26,0))



t= np.arange(0,360)*411/360

plt.plot(t,i,color=(1,0,0),label = "PB2")
plt.fill_between(t, i-j,  i+j, alpha = 0.2,color=(1,0,0))

t= np.arange(0,352)*387/352
plt.plot(t,it,color=(1,0,1),label = "PBT")
plt.fill_between(t, it-jt,  it+jt, alpha = 0.2,color=(1,0,1))




axes = plt.gca()
axes.set_ylim(0.015,.2)
axes.set_ylabel('MSE error',fontsize=16)

axes.set_xlabel('execution time (s)',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#axes.set_title('Comparison on test Boston with 10 experiment')
#plt.title(r'\underline{Validation loss}:')
axes.set_yscale('log')
#plt.legend()
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.tight_layout()
plt.savefig('Boston_test.pdf')

# %%
#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')
t= np.arange(0,360)*375/360

plt.plot(t,c,c='b',label = "c=2")
#plt.fill_between(t, c-d,  c+d, alpha = 0.2,color='b')


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c4,c='y',label = "c=4")
#plt.fill_between(t, c4-d4,  c4+d4, alpha = 0.2,color='y')


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c14,c='c',label = "c=1/4")
#plt.fill_between(t, c14-d14,  c14+d14, alpha = 0.2,color='c')

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c8,c='r',label = "c=8")
#plt.fill_between(t, c4-d4,  c4+d4, alpha = 0.2,color='y')


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c18,c='g',label = "c=1/8")
#plt.fill_between(t, c14-d14,  c14+d14, alpha = 0.2,color='c')

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c1,c='grey',label = "c=1")
#plt.fill_between(t, c14-d14,  c14+d14, alpha = 0.2,color='c')


#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c2,c='m',label = "c=1/2")
#plt.fill_between(t, c14-d14,  c14+d14, alpha = 0.2,color='c')

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,c3,c='purple',label = "c=1/2_no time")
#plt.fill_between(t, c14-d14,  c14+d14, alpha = 0.2,color='c')



t= np.arange(0,352)*387/352
plt.plot(t,kt,"k--",label = "PBT")



axes = plt.gca()
axes.set_ylim(0.015,.1)
axes.set_ylabel('error')

axes.set_xlabel('execution time (s)')
axes.set_title('Comparison of varying c on val Boston with 10 experiment with TPE')
#plt.title(r'\underline{Validation loss}:')
axes.set_yscale('log')
plt.legend()
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.tight_layout()
plt.savefig('Boston_val_comp_c.pdf')

# %%
#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')
t= np.arange(0,360)*375/360

plt.plot(t,a,color=(1,0,0),label = "color=2")
#plt.fill_between(t, a-b,  a+b, alpha = 0.2,color='b')


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a4,color=(0,0,1),label = "color=4")
#plt.fill_between(t, a4-b4,  a4+b4, alpha = 0.2,color='y')


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a14,color=(0,1,1),label = "color=1/4")
#plt.fill_between(t, a14-b14,  a14+b14, alpha = 0.2,color='c')

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a8,color=(0,1,0),label = "color=8")
#plt.fill_between(t, a8-b8,  a8+b8, alpha = 0.2,color='r')


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a18,color=(1,1,0),label = "color=1/8")
#plt.fill_between(t, a18-b18,  a18+b18, alpha = 0.2,color='g')

t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a1,color=(0,0,0),label = "color=1")
#plt.fill_between(t, a1-b1,  a1+b1, alpha = 0.2,color='grey')


#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a2,color=(.45,.26,0),label = "color=1/2")
#plt.fill_between(t, a2-b2,  a2+b2, alpha = 0.2,color='m')

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a3,color=(.33,.33,.33),label = "color=1/2_no time")
#plt.fill_between(t, a3-b3,  a3+b3, alpha = 0.2,color='purple')



t= np.arange(0,352)*387/352
plt.plot(t,it,color=(1,0,1),linestyle = '--',label = "PBT")
#plt.fill_between(t, it-jt,  it+jt, alpha = 0.2,color='k')



axes = plt.gca()
axes.set_ylim(0.015,.2)
axes.set_ylabel('MSE error',fontsize=16)

axes.set_xlabel('execution time (s)',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
#axes.set_title('Comparison of varying c on test Boston with 10 experiment with TPE')
#plt.title(r'\underline{Validation loss}:')
axes.set_yscale('log')
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.tight_layout()
#plt.legend()
plt.savefig('Boston_test_comp_c.pdf')

# %%
#[m,n,o,p] = getall(np.concatenate((random1,random2,random3,random4,random5),axis=1))

#np.savetxt('our_old.csv', np.array([t,a,b,c,d]).T, delimiter=',')




t= np.arange(0,224)*269/224
plt.plot(t,m,c='r',label = "BOHB")
plt.fill_between(t, m-n,  m+n, alpha = 0.2,color='r')


t= np.arange(0,360)*369/360
plt.plot(t,e,c='g',label = "hyper")
plt.fill_between(t, e-f,  e+f, alpha = 0.2,color='g')


t= np.arange(0,360)*375/360

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a2,c='b',label = "c=1/2")
plt.fill_between(t, a2-b2,  a2+b2, alpha = 0.2,color='b')

#plt.fill_between(t, c4-d4,  c4+d4, alpha = 0.2,color='y')

#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a3,c='c',label = "c=1/2_no time")
plt.fill_between(t, a3-b3,  a3+b3, alpha = 0.2,color='c')

plt.plot(t,xa,c='grey',label = "c=1/2_cma")
plt.fill_between(t, xa-xb,  xa+xb, alpha = 0.2,color='grey')

t= np.arange(0,360)*400/360
#np.savetxt('hyper.csv', np.array([t,e,f,g,h]).T, delimiter=',')
plt.plot(t,a4,c='orange',label = "c=1/2_GP_time")
plt.fill_between(t, a4-b4,  a4+b4, alpha = 0.2,color='orange')



t= np.arange(0,360)*411/360

plt.plot(t,i,c='m',label = "PB2")
plt.fill_between(t, i-j,  i+j, alpha = 0.2,color='m')

t= np.arange(0,352)*387/352
plt.plot(t,it,c='k',label = "PBT")
plt.fill_between(t, it-jt,  it+jt, alpha = 0.2,color='k')




axes = plt.gca()
axes.set_ylim(0.015,.2)
axes.set_ylabel('error')

axes.set_xlabel('execution time (s)')
axes.set_title('Comparison on test Boston with 10 experiment')
#plt.title(r'\underline{Validation loss}:')
axes.set_yscale('log')
plt.legend()
fig = plt.gcf()
fig.set_size_inches(8, 4)
plt.tight_layout()
plt.savefig('Boston_test.pdf')

# %%
t= np.arange(0,224)*269/224
plt.plot(t,m,c='r',label = "BOHB")
plt.plot(t,o,c='r',label = "BOHB")


t= np.arange(0,360)*369/360
plt.plot(t,e,c='g',label = "hyper")
plt.plot(t,g,c='g',label = "hyper")

t= np.arange(0,360)*411/360


plt.plot(t,i,c='m',label = "PB2")
plt.plot(t,k,c='m',label = "PB2")

t= np.arange(0,352)*387/352

plt.plot(t,it,c='k',label = "PBT")
plt.plot(t,kt,c='k',label = "PBT")


axes = plt.gca()
axes.set_ylim(0.016,.2)
axes.set_yscale('log')

# %%
import pandas as pd
from numpy import genfromtxt
import numpy as np
from scipy.interpolate import *
import matplotlib.pyplot as plt


def fonc(data):
    itera = data[:,5:6]
    itera= itera[~np.isnan(itera)]
    dat = data[:,0:2]
    dat = dat[~np.isnan(dat)]
    dat = dat.reshape(-1,2)
  #  dat = dat[np.argsort(itera,axis=-1)]
    return dat
string = "data_brut/Boston4/"
pb1 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_1.csv', delimiter=',')
pb2 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_2.csv', delimiter=',')
pb3 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_3.csv', delimiter=',')
pb4 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_4.csv', delimiter=',')
pb5 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_5.csv', delimiter=',')
pb6 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_6.csv', delimiter=',')
pb7 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_7.csv', delimiter=',')
pb8 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_8.csv', delimiter=',')
pb9 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_11.csv', delimiter=',')
pb10 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_10.csv', delimiter=',')




pb1 = fonc(pb1)
pb2 = fonc(pb2)
pb3 = fonc(pb3)
pb4 = fonc(pb4)
pb5 = fonc(pb5)
pb6 = fonc(pb6)
pb7 = fonc(pb7)
pb8 = fonc(pb8)
pb9 = fonc(pb9)
pb10 = fonc(pb10)


pb1= maxof(pb1)
pb2=maxof(pb2)
pb3=maxof(pb3)
pb4=maxof(pb4)
pb5=maxof(pb5)
pb6= maxof(pb6)
pb7=maxof(pb7)
pb8=maxof(pb8)
pb9=maxof(pb9)
pb10=maxof(pb10)
pb1= np.array(pb1)
pb2 = np.array(pb2)
#print(pb1.shape)
# Out:
# (310, 2)
# (311, 2)
# (312, 2)
# (313, 2)
# (314, 2)
# (315, 2)
# (316, 2)
# (317, 2)
# (318, 2)
# (319, 2)
# (320, 2)
# (321, 2)
# (322, 2)
# (323, 2)
# (324, 2)
# (325, 2)
# (326, 2)
# (327, 2)
# (328, 2)
# (329, 2)
# (330, 2)
# (331, 2)
# (332, 2)
# (333, 2)
# (334, 2)
# (335, 2)
# (336, 2)
# (337, 2)
# (338, 2)
# (339, 2)
# (340, 2)
# (341, 2)
# (342, 2)
# (343, 2)
# (344, 2)
# (345, 2)
# (346, 2)
# (347, 2)
# (348, 2)
# (349, 2)
# (350, 2)
# (351, 2)
# (352, 2)
# (353, 2)
# (354, 2)
# (355, 2)
# (356, 2)
# (357, 2)
# (358, 2)
# (359, 2)
# (360, 2)
# (341, 2)
# (342, 2)
# (343, 2)
# (344, 2)
# (345, 2)
# (346, 2)
# (347, 2)
# (348, 2)
# (349, 2)
# (350, 2)
# (351, 2)
# (352, 2)
# (353, 2)
# (354, 2)
# (355, 2)
# (356, 2)
# (357, 2)
# (358, 2)
# (359, 2)
# (360, 2)
# (357, 2)
# (358, 2)
# (359, 2)
# (360, 2)
# (331, 2)
# (332, 2)
# (333, 2)
# (334, 2)
# (335, 2)
# (336, 2)
# (337, 2)
# (338, 2)
# (339, 2)
# (340, 2)
# (341, 2)
# (342, 2)
# (343, 2)
# (344, 2)
# (345, 2)
# ...

# %%
plt.plot(pb9)
axes = plt.gca()
axes.set_ylim(0.016,2)
axes.set_yscale('log')

# %%
import pandas as pd
from numpy import genfromtxt
import numpy as np
from scipy.interpolate import *
import matplotlib.pyplot as plt


def fonc(data):
    itera = data[:,5:6]
    itera= itera[~np.isnan(itera)]
    dat = data[:,0:2]
    dat = dat[~np.isnan(dat)]
    dat = dat.reshape(-1,2)
  #  dat = dat[np.argsort(itera,axis=-1)]
    return dat[:,::-1]
string = "data_brut/Boston3/"
pbt1 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_1.csv', delimiter=',')
pbt2 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_2.csv', delimiter=',')
pbt3 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_3.csv', delimiter=',')
pbt4 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_4.csv', delimiter=',')
pbt5 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_5.csv', delimiter=',')
pbt6 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_6.csv', delimiter=',')
pbt7 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_7.csv', delimiter=',')
pbt8 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_8.csv', delimiter=',')
pbt9 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_9.csv', delimiter=',')
pbt10 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_PB2_10.csv', delimiter=',')




pbt1 = fonc(pbt1)
pbt2 = fonc(pbt2)
pbt3 = fonc(pbt3)
pbt4 = fonc(pbt4)
pbt5 = fonc(pbt5)
pbt6 = fonc(pbt6)
pbt7 = fonc(pbt7)
pbt8 = fonc(pbt8)
pbt9 = fonc(pbt9)
pbt10 = fonc(pbt10)


pbt1= maxof(pbt1[:,::-1])
pbt2=maxof(pbt2[:,::-1])
pbt3=maxof(pbt3[:,::-1])
pbt4=maxof(pbt4[:,::-1])
pbt5=maxof(pbt5[:,::-1])
pbt6= maxof(pbt6[:,::-1])
pbt7=maxof(pbt7[:,::-1])
pbt8=maxof(pbt8[:,::-1])
pbt9=maxof(pbt9[:,::-1])
pbt10=maxof(pbt10[:,::-1])
# Out:
# (325, 2)
# (326, 2)
# (327, 2)
# (328, 2)
# (329, 2)
# (330, 2)
# (331, 2)
# (332, 2)
# (333, 2)
# (334, 2)
# (335, 2)
# (336, 2)
# (337, 2)
# (338, 2)
# (339, 2)
# (340, 2)
# (341, 2)
# (342, 2)
# (343, 2)
# (344, 2)
# (345, 2)
# (346, 2)
# (347, 2)
# (348, 2)
# (349, 2)
# (350, 2)
# (351, 2)
# (352, 2)
# (353, 2)
# (354, 2)
# (355, 2)
# (356, 2)
# (357, 2)
# (358, 2)
# (359, 2)
# (360, 2)
# (330, 2)
# (331, 2)
# (332, 2)
# (333, 2)
# (334, 2)
# (335, 2)
# (336, 2)
# (337, 2)
# (338, 2)
# (339, 2)
# (340, 2)
# (341, 2)
# (342, 2)
# (343, 2)
# (344, 2)
# (345, 2)
# (346, 2)
# (347, 2)
# (348, 2)
# (349, 2)
# (350, 2)
# (351, 2)
# (352, 2)
# (353, 2)
# (354, 2)
# (355, 2)
# (356, 2)
# (357, 2)
# (358, 2)
# (359, 2)
# (360, 2)
# (335, 2)
# (336, 2)
# (337, 2)
# (338, 2)
# (339, 2)
# (340, 2)
# (341, 2)
# (342, 2)
# (343, 2)
# (344, 2)
# (345, 2)
# (346, 2)
# (347, 2)
# (348, 2)
# (349, 2)
# (350, 2)
# (351, 2)
# (352, 2)
# (353, 2)
# (354, 2)
# (355, 2)
# (356, 2)
# (357, 2)
# ...

# %%
string = "data_brut/Boston3/"


b1 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB0.csv', delimiter=',')
b2 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB1.csv', delimiter=',')
b3 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB2.csv', delimiter=',')
b4 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB3.csv', delimiter=',')
b5 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB4.csv', delimiter=',')
b6 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB5.csv', delimiter=',')
b7 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB6.csv', delimiter=',')
b8 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB7.csv', delimiter=',')
b9 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB8.csv', delimiter=',')
b10 = genfromtxt('/home/antoine/GPBT/FSN/'+string+'Boston_BOHB9.csv', delimiter=',')

b1 = fonc(b1)
b2 = fonc(b2)
b3 = fonc(b3)
b4 = fonc(b4)
b5 = fonc(b5)
b6 = fonc(b6)
b7 = fonc(b7)
b8 = fonc(b8)
b9 = fonc(b9)
b10 = fonc(b10)


_b1= maxof(b1[:,::-1])
_b2=maxof(b2[:,::-1])
_b3=maxof(b3[:,::-1])
_b4=maxof(b4[:,::-1])
_b5=maxof(b5[:,::-1])
_b6= maxof(b6[:,::-1])
_b7=maxof(b7[:,::-1])
_b8=maxof(b8[:,::-1])
_b9=maxof(b9[:,::-1])
_b10=maxof(b10[:,::-1])
# Out:
# (215, 2)
# (216, 2)
# (217, 2)
# (218, 2)
# (219, 2)
# (220, 2)
# (221, 2)
# (222, 2)
# (223, 2)
# (224, 2)
# (225, 2)
# (226, 2)
# (227, 2)
# (228, 2)
# (229, 2)
# (230, 2)
# (231, 2)
# (232, 2)
# (233, 2)
# (234, 2)
# (235, 2)
# (236, 2)
# (237, 2)
# (238, 2)
# (239, 2)
# (240, 2)
# (241, 2)
# (242, 2)
# (243, 2)
# (244, 2)
# (245, 2)
# (246, 2)
# (247, 2)
# (248, 2)
# (249, 2)
# (250, 2)
# (251, 2)
# (252, 2)
# (253, 2)
# (254, 2)
# (255, 2)
# (256, 2)
# (257, 2)
# (258, 2)
# (259, 2)
# (260, 2)
# (261, 2)
# (262, 2)
# (263, 2)
# (264, 2)
# (265, 2)
# (266, 2)
# (267, 2)
# (268, 2)
# (269, 2)
# (270, 2)
# (271, 2)
# (272, 2)
# (273, 2)
# (274, 2)
# (275, 2)
# (276, 2)
# (277, 2)
# (278, 2)
# (279, 2)
# (280, 2)
# (281, 2)
# (282, 2)
# (283, 2)
# (284, 2)
# (285, 2)
# (286, 2)
# (287, 2)
# (288, 2)
# (289, 2)
# (290, 2)
# (291, 2)
# (292, 2)
# (293, 2)
# (294, 2)
# (295, 2)
# (296, 2)
# (297, 2)
# (298, 2)
# (299, 2)
# (300, 2)
# (301, 2)
# (302, 2)
# (303, 2)
# (304, 2)
# ...

# %%
b1.shape
# Out:
# (360, 2)

# %%
b5.shape
# Out:
# (360, 2)

# %%
b10.shape
# Out:
# (360, 2)

# %%
tempb1 = genfromtxt('/home/antoine/GPBT/FSN/'+'data_brut/Boston/'+'BOHB_Boston1.csv', delimiter=',')
arg = tempb1[:,0:2]
print(arg.shape)
nop = np.isnan(arg)
temp = maxof(arg[~nop].reshape(-1,2))
print(temp.shape)
plt.plot(temp[:,0]-temp[:,1])
# Out:
# (2574, 2)
# (360, 2)

# %%
plt.plot(t, mean_test_3, 'k-',label="test ax")
plt.fill_between(t, mean_test_3-std_test_3,  mean_test_3+std_test_3, alpha = 0.2,color='k')

plt.plot(t, mean_val_3, 'b--',label="val ax")
plt.fill_between(t, mean_val_3-std_val_3,  mean_val_3+std_val_3, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.78,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/5.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_4, 'k-',label="test NeverGrad")
plt.fill_between(t, mean_test_4-std_test_4,  mean_test_4+std_test_4, alpha = 0.2,color='k')

plt.plot(t, mean_val_4, 'b--',label="val NeverGrad")
plt.fill_between(t, mean_val_4-std_val_4,  mean_val_4+std_val_4, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.006,0.018)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/124.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_5, 'k-',label="test bohb")
plt.fill_between(t, mean_test_5-std_test_5,  mean_test_5+std_test_5, alpha = 0.2,color='k')

plt.plot(t, mean_val_5, 'b--',label="val bohb")
plt.fill_between(t, mean_val_5-std_val_5,  mean_val_5+std_val_5, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.85,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/306.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_6, 'k-',label="test random")
plt.fill_between(t, mean_test_6-std_test_6,  mean_test_6+std_test_6, alpha = 0.2,color='k')

plt.plot(t, mean_val_6, 'b--',label="val random")
plt.fill_between(t, mean_val_6-std_val_6,  mean_val_6+std_val_6, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.85,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/307.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_7, 'k-',label="test zoopt")
plt.fill_between(t, mean_test_7-std_test_7,  mean_test_7+std_test_7, alpha = 0.2,color='k')

plt.plot(t, mean_val_7, 'b--',label="val zoopt")
plt.fill_between(t, mean_val_7-std_val_7,  mean_val_7+std_val_7, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.006,0.018)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/127.png')

fig = plt.figure()
plt.show()
