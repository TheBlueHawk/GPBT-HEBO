# %%
import math
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a


x = np.arange(-10., 10., 0.2)
sig = sigmoid(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

plt.plot(x,sig)
plt.show()

# %%
def f():
    j=0
    tmp=ax
    tmp.plot(Hyper[j:j+2])
    tmp.plot(Bayes[j:j+2])
    tmp.plot(Ax[j:j+2])
    tmp.plot(NG[j:j+2])
    tmp.plot(BOHB[j:j+2])
    tmp.plot(Ran[j:j+2])
    tmp.plot(Zoo[j:j+2])
    #ax1.spines['left'].set_position(('data', -1.142))


    tmp=ax1
    j=1
    tmp.plot(Hyper[j:j+2])
    tmp.plot(Bayes[j:j+2])
    tmp.plot(Ax[j:j+2])
    tmp.plot(NG[j:j+2])
    tmp.plot(BOHB[j:j+2])
    tmp.plot(Ran[j:j+2])
    tmp.plot(Zoo[j:j+2])

    for i in range(7):
        j=0


    
    
# Implementation of matplotlib function 
import matplotlib.pyplot as plt 
import numpy as np 
from matplotlib.colors import LogNorm 
   
Z = np.random.rand(6, 30) 

fig, (ax, ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 6) 

#ax.pcolor(Z) 
#ax1.pcolor(Z) 

chartBox = ax1.get_position() 
ax1.set_position([chartBox.x0-0.022,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax2.get_position() 
ax2.set_position([chartBox.x0-0.044,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax3.get_position() 
ax3.set_position([chartBox.x0-0.066,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax4.get_position() 
ax4.set_position([chartBox.x0-0.088,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax5.get_position() 
ax6=ax5.twinx()
ax5.set_position([chartBox.x0-0.112,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
  
    
ax0=ax.twinx()

ax.set_xticks([])

ax1.set_xticks([])
ax2.set_xticks([])
ax3.set_xticks([])
ax4.set_xticks([])
ax5.set_xticks([])
ax6.set_xticks([])

f()
    
ax.set_title("MNIST",x=0,y=-0.2,rotation=270) 
ax1.set_title("FMNIST",x=0,y=-0.235,rotation=270) 
ax2.set_title("GAN",x=0,y=-0.15,rotation=270) 
ax3.set_title("IMDB",x=0,y=-0.175,rotation=270) 
ax4.set_title("TREC",x=0,y=-0.165,rotation=270) 
ax6.set_title("BOSTON",x=0,y=-0.26,rotation=270) 
ax5.set_title("DIABETE",x=1,y=-0.26,rotation=270) 

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

def format(input):
    if input == "N":
        output = 0
    elif input == "N-1":
        output = 1
    else:
        output = None
    return output

df2 = pd.DataFrame([["line 1",20,30,100,"N"],\
    ["line 2",10,40,90,"N"],["line 3",10,35,120,"N-1"]],\
    columns=["element","var 1","var 2","var 3","regime"])
df2["regime_encoded"] = df2["regime"].apply(format) * max(df2[["var 1","var 2","var 3"]].max(axis=1))

parallel_coordinates(df2[['element', 'var 1', 'var 2', 'var 3', 'regime_encoded']],"element")
ax = plt.gca()
for i,(label,val) in df2.ix[:,['regime','regime_encoded']].drop_duplicates().iterrows():
    ax.annotate(label, xy=(3,val), ha='left', va='center')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-205-cfbb4ed57964> in <module>
#      19 parallel_coordinates(df2[['element', 'var 1', 'var 2', 'var 3', 'regime_encoded']],"element")
#      20 ax = plt.gca()
# ---> 21 for i,(label,val) in df2.ix[:,['regime','regime_encoded']].drop_duplicates().iterrows():
#      22     ax.annotate(label, xy=(3,val), ha='left', va='center')
#      23
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
#!/usr/bin/python
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def parallel_coordinates(data_sets, style=None):

    dims = len(data_sets[0])
    x    = range(dims)
    fig, axes = plt.subplots(1, dims-1, sharey=False)

    if style is None:
        style = ['r-']*len(data_sets)

    # Calculate the limits on the data
    min_max_range = list()
    tmps=-1
    for m in zip(*data_sets):
        tmps+=1
        mn = min(m)
        mx = max(m)
        if mn == mx:
            mn -= 0.5
            mx = mn + 1.
        r  = float(mx - mn)
        if(tmps==3 or tmp==5 or tmp==6):
            min_max_range.append((mn, mx, r))
        else:
            min_max_range.append((mn, mx, r))

    # Normalize the data sets
    norm_data_sets = list()
    for ds in data_sets:
        nds = [(value - min_max_range[dimension][0]) / 
                min_max_range[dimension][2] 
                for dimension,value in enumerate(ds)]
        norm_data_sets.append(nds)
    data_sets = norm_data_sets

    # Plot the datasets on all the subplots
    for i, ax in enumerate(axes):

        for dsi, d in enumerate(data_sets):
            ax.plot(x, d, style[dsi])
        ax.set_xlim([x[i], x[i+1]])

    # Set the x axis ticks 
    for dimension, (axx,xx) in enumerate(zip(axes, x[:-1])):

        axx.xaxis.set_major_locator(ticker.FixedLocator([xx]))
        ticks = len(axx.get_yticklabels())
        labels = list()
        step = min_max_range[dimension][2] / (ticks - 1)
        mn   = min_max_range[dimension][0]
        for i in range(ticks):
            v = mn + i*step
            labels.append('%4.2f' % v)
        axx.set_yticklabels(labels)
        


    # Move the final axis' ticks to the right-hand side
    axx = plt.twinx(axes[-1])
    dimension += 1

    axx.xaxis.set_major_locator(ticker.FixedLocator([x[-2], x[-1]]))
    ticks = len(axx.get_yticklabels())
    step = min_max_range[dimension][2] / (ticks - 1)
    mn   = min_max_range[dimension][0]
    labels = ['%4.2f‰' % ((mn + i*step)*1000) for i in range(ticks)]
    axx.set_yticklabels(labels)
    # Stack the subplots 
    plt.subplots_adjust(wspace=0)

    return plt

g()
# Out:
# /home/antoine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:57: UserWarning: FixedFormatter should only be used together with FixedLocator
# /home/antoine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:70: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
def g():
# if __name__ == '__main__':
    import random
    
    n=7
    
    base  = [0.785,0.890275,6.443702104245254,0.172876
,0.851736, 0.009040117499999998,5.6/1000

]
    scale = [1.5, 2., 1.0, 2., 2.]
    data = [[base[x] + random.uniform(0., 1.)*0
            for x in range(n)] for y in range(30)]
    colors = ['r'] * 30

    base  = [0.789,0.88805,6.325708590132482,0.181469

,0.8258682,0.0094340925,5.5/1000

]
    data.extend([[base[x] + random.uniform(0., 1.)*0
                 for x in range(n)] for y in range(30)])
    
    colors.extend(['c'] * 30)
    
    base  = [0.817,0.88305,6.133054804498614,0.2001695

,0.8322516,0.0099675775,5.6/1000

]
    data.extend([[base[x] + random.uniform(0., 1.)*0
                 for x in range(n)] for y in range(30)])
    
    colors.extend(['b'] * 30)  
    base  = [0.8,0.884175,6.290438322234702,0.195501

,0.8284853999999999,0.00924797,5.5/1000
]
    data.extend([[base[x] + random.uniform(0., 1.)*0
                 for x in range(n)] for y in range(30)])
    
    colors.extend(['g'] * 30)  
    base  = [0.785,0.8876999999999999,6.173551552576356,0.20235175


,0.8523637500000001,0.01089995,5.8/1000
]
    data.extend([[base[x] + random.uniform(0., 1.)*0
                 for x in range(n)] for y in range(30)])
    
    colors.extend(['k'] * 30)    
    base  = [0.787,0.8829750000000001,6.170678868638696,0.19178825

,0.8329594,0.0128378175,5.8/1000
]
    data.extend([[base[x] + random.uniform(0., 1.)*0
                 for x in range(n)] for y in range(30)])
    
    colors.extend(['m'] * 30)

    base  = [0.795,0.884625,6.325670890740688,0.217812

,0.8260818000000001,0.00912089,6.2/1000]
    data.extend([[base[x] + random.uniform(0., 1.)*0
                 for x in range(n)] for y in range(30)])
    
    colors.extend(['y'] * 30)
    
    
    parallel_coordinates(data, style=colors).show()

# %%
def parallel_coordinates(frame, class_column, cols=None, ax=None, color=None,
                     use_columns=False, xticks=None, colormap=None,
                     **kwds):
    import matplotlib.pyplot as plt
    import matplotlib as mpl

    n = len(frame)
    class_col = frame[class_column]
    class_min = np.amin(class_col)
    class_max = np.amax(class_col)

    if cols is None:
        df = frame.drop(class_column, axis=1)
    else:
        df = frame[cols]

    used_legends = set([])

    ncols = len(df.columns)

    # determine values to use for xticks
    if use_columns is True:
        if not np.all(np.isreal(list(df.columns))):
            raise ValueError('Columns must be numeric to be used as xticks')
        x = df.columns
    elif xticks is not None:
        if not np.all(np.isreal(xticks)):
            raise ValueError('xticks specified must be numeric')
        elif len(xticks) != ncols:
            raise ValueError('Length of xticks must match number of columns')
        x = xticks
    else:
        x = range(ncols)

    fig = plt.figure()
    ax = plt.gca()

    Colorm = plt.get_cmap(colormap)

    for i in range(n):
        y = df.iloc[i].values
        kls = class_col.iat[i]
        ax.plot(x, y, color=Colorm((kls - class_min)/(class_max-class_min)), **kwds)

    for i in x:
        ax.axvline(i, linewidth=1, color='black')

    ax.set_xticks(x)
    ax.set_xticklabels(df.columns)
    ax.set_xlim(x[0], x[-1])
    ax.legend(loc='upper right')
    ax.grid()

    bounds = np.linspace(class_min,class_max,10)
    cax,_ = mpl.colorbar.make_axes(ax)
    cb = mpl.colorbar.ColorbarBase(cax, cmap=Colorm, spacing='proportional', ticks=bounds, boundaries=bounds, format='%.2f')

    return fig
parallel_coordinates(df2,"element")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-302-a96152055ccb> in <module>
#      57
#      58     return fig
# ---> 59 parallel_coordinates(df2,"element")
#
# <ipython-input-302-a96152055ccb> in parallel_coordinates(frame, class_column, cols, ax, color, use_columns, xticks, colormap, **kwds)
#      41         y = df.iloc[i].values
#      42         kls = class_col.iat[i]
# ---> 43         ax.plot(x, y, color=Colorm((kls - class_min)/(class_max-class_min)), **kwds)
#      44
#      45     for i in x:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import numpy as np

fig, host = plt.subplots()

# create some dummy data
ynames = ['MNIST', 'FMNIST', 'GAN', 'IMDB', 'TREC','BOSTON','DIABETE']
N1, N2, N3,N4,N5,N6,N7 = 1,1,1,1,1, 1,1
N = N1+N2+N3+N4+N5+N6+N7

category = np.concatenate([np.full(N1, 1), np.full(N2, 2), np.full(N3, 3),
                          np.full(N4, 4),np.full(N3, 5),np.full(N3, 6)
                          ,np.full(N3, 7)])

print(new[0])
y1=np.array(new[0])
print(y1.shape)
y2=np.array(new[1])
print(y2.shape)
y3=np.array(new[2])
print(y3.shape)
y4=np.array(new[3])
print(y4.shape)
y5=np.array(new[4])
print(y5.shape)
y6=np.array(new[5])
print(y5.shape)
y7=np.array(new[6])
print(y5.shape)
# organize the data
ys = np.dstack([y1, y2, y3, y4, y5,y6,y7])[0]
print(ys)
ymins = ys.min(axis=0)
ymaxs = ys.max(axis=0)
dys = ymaxs - ymins
ymins -= dys * 0.05  # add 5% padding below and above
ymaxs += dys * 0.05
dys = ymaxs - ymins

# transform all data to be compatible with the main axis
print(ys[:,3])
ys[:,3]= 0.19525*2-ys[:,3]
ys[:,5]= 0.01092*2-ys[:,5]
ys[:,6]= 0.00616*1.9-ys[:,6]


zs = np.zeros_like(ys)
zs[:, 0] = ys[:, 0]
zs[:, 1:] = (ys[:, 1:] - ymins[1:]) / dys[1:] * dys[0] + ymins[0]


axes = [host] + [host.twinx() for i in range(ys.shape[1] - 1)]
for i, ax in enumerate(axes):
    if(i==3 or i==6 or i==5):
        ax.set_ylim( ymaxs[i],ymins[i])
        
    else:
        ax.set_ylim(ymins[i], ymaxs[i])
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    if ax != host:
        ax.spines['left'].set_visible(False)
        ax.yaxis.set_ticks_position('right')
        ax.spines["right"].set_position(("axes", i / (ys.shape[1] - 1)))

host.set_xlim(0, ys.shape[1] - 1)
host.set_xticks(range(ys.shape[1]))
host.set_xticklabels(ynames, fontsize=14,rotation=90)
host.tick_params(axis='x', which='major', pad=7)
host.spines['right'].set_visible(False)
host.xaxis.tick_top()

colors = plt.cm.tab10.colors
for j in range(N):
    # to just draw straight lines between the axes:
    #host.plot(range(ys.shape[1]), zs[j,:], c=colors[(category[j] - 1) % len(colors) ])

    # create bezier curves
    # for each axis, there will a control vertex at the point itself, one at 1/3rd towards the previous and one
    #   at one third towards the next axis; the first and last axis have one less control vertex
    # x-coordinate of the control vertices: at each integer (for the axes) and two inbetween
    # y-coordinate: repeat every point three times, except the first and last only twice
    verts = list(zip([x for x in np.linspace(0, len(ys) - 1, len(ys) * 3 - 2, endpoint=True)],
                     np.repeat(zs[j, :], 3)[1:-1]))
    #for x,y in verts: host.plot(x, y, 'go') # to show the control points of the beziers
    codes = [Path.MOVETO] + [Path.CURVE4 for _ in range(len(verts) - 1)]
    path = Path(verts, codes)
    colors=['r','c','b','g','k','m','y']
    patch = patches.PathPatch(path, facecolor='none', lw=1, edgecolor=colors[category[j] - 1])
    host.add_patch(patch)
    
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
line1 = mlines.Line2D([], [], color='r', marker='_'
, label='Hyper')
line2 = mlines.Line2D([], [], color='c', marker='_'
, label='Bayes')
line3 = mlines.Line2D([], [], color='b', marker='_'
, label='Ax')
line4 = mlines.Line2D([], [], color='g', marker='_'
, label='NeverGrad')
line5 = mlines.Line2D([], [], color='k', marker='_'
, label='BOHB')
line6 = mlines.Line2D([], [], color='m', marker='_'
, label='Random')
line7 = mlines.Line2D([], [], color='y', marker='_'
, label='Zoopt')
plt.legend(handles=[line1,line2,line3,line4,line5,line6,line7],loc = 'upper left',bbox_to_anchor=(1.1,0.995 ))
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 5
plt.tight_layout()

plt.savefig('OVERALL.png')
#plt.show()
# Out:
# [0.785 0.789 0.817 0.8   0.785 0.787 0.795]
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# (7,)
# [[7.85000000e-01 8.90275000e-01 6.44370210e+00 1.72876000e-01
#   8.51736000e-01 9.04011750e-03 5.60000000e-03]
#  [7.89000000e-01 8.88050000e-01 6.32570859e+00 1.81469000e-01
#   8.25868200e-01 9.43409250e-03 5.50000000e-03]
#  [8.17000000e-01 8.83050000e-01 6.13305480e+00 2.00169500e-01
#   8.32251600e-01 9.96757750e-03 5.60000000e-03]
#  [8.00000000e-01 8.84175000e-01 6.29043832e+00 1.95501000e-01
#   8.28485400e-01 9.24797000e-03 5.50000000e-03]
#  [7.85000000e-01 8.87700000e-01 6.17355155e+00 2.02351750e-01
#   8.52363750e-01 1.08999500e-02 5.80000000e-03]
#  [7.87000000e-01 8.82975000e-01 6.17067887e+00 1.91788250e-01
#   8.32959400e-01 1.28378175e-02 5.80000000e-03]
#  [7.95000000e-01 8.84625000e-01 6.32567089e+00 2.17812000e-01
#   8.26081800e-01 9.12089000e-03 6.20000000e-03]]
# [0.172876   0.181469   0.2001695  0.195501   0.20235175 0.19178825
#  0.217812  ]

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)

# %%
plt.figure(figsize=(12,9), dpi= 80)
parallel_coordinates(df,class_column = "element"  ,colormap='Dark2')


# Lighten borders
plt.gca().spines["top"].set_alpha(0)
plt.gca().spines["bottom"].set_alpha(.3)
plt.gca().spines["right"].set_alpha(0)
plt.gca().spines["left"].set_alpha(.3)

plt.title('Parallel Coordinated of Diamonds', fontsize=22)
plt.grid(alpha=0.3)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
new = np.array((hyper,bayes,ax,ng,bohb,ran,zoo))
new = new.T

# %%
    hyper  = [0.785,0.890275,6.443702104245254,0.172876
,0.851736, 0.009040117499999998,5.6/1000

]
 

    bayes  = [0.789,0.88805,6.325708590132482,0.181469

,0.8258682,0.0094340925,5.5/1000

]

    
    ax  = [0.817,0.88305,6.133054804498614,0.2001695

,0.8322516,0.0099675775,5.6/1000

]

    ng  = [0.8,0.884175,6.290438322234702,0.195501

,0.8284853999999999,0.00924797,5.5/1000
]

    bohb  = [0.785,0.8876999999999999,6.173551552576356,0.20235175


,0.8523637500000001,0.01089995,5.8/1000
]
    
    ran  = [0.787,0.8829750000000001,6.170678868638696,0.19178825

,0.8329594,0.0128378175,5.8/1000
]

    zoo  = [0.795,0.884625,6.325670890740688,0.217812

,0.8260818000000001,0.00912089,6.2/1000]

# %%
fig, (ax, ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 6) 

chartBox = ax1.get_position() 
ax1.set_position([chartBox.x0-0.022,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax2.get_position() 
ax2.set_position([chartBox.x0-0.044,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax3.get_position() 
ax3.set_position([chartBox.x0-0.066,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax4.get_position() 
ax4.set_position([chartBox.x0-0.088,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 
chartBox = ax5.get_position() 
ax6=ax5.twinx()
ax5.set_position([chartBox.x0-0.112,  
                  chartBox.y0, 
                  chartBox.width, 
                  chartBox.height]) 



ax.set_xticks([])
ax1.set_xticks([])
ax2.set_xticks([])
ax3.set_xticks([])
ax4.set_xticks([])
ax5.set_xticks([])
ax6.set_xticks([])

Hyper=[0.785,0.890275,6.443702104245254
]
Bayes=[0.789,0.88805,6.325708590132482

]
Ax=[0.817,0.885175,6.133054804498614

]
NG=[0.8,0.884825,6.290438322234702

]
BOHB=[0.785,0.8876999999999999,6.173551552576356


]
Ran=[0.787,0.884175,6.170678868638696

]
Zoo=[0.795,0.884625,6.325670890740688

]

j=0
tmp=ax
tmp.plot(Hyper[j:j+2])
tmp.plot(Bayes[j:j+2])
tmp.plot(Ax[j:j+2])
tmp.plot(NG[j:j+2])
tmp.plot(BOHB[j:j+2])
tmp.plot(Ran[j:j+2])
tmp.plot(Zoo[j:j+2])


tmp=ax1
j=1
tmp.plot(Hyper[j:j+2])
tmp.plot(Bayes[j:j+2])
tmp.plot(Ax[j:j+2])
tmp.plot(NG[j:j+2])
tmp.plot(BOHB[j:j+2])
tmp.plot(Ran[j:j+2])
tmp.plot(Zoo[j:j+2])

plt.show()

# %%
Hyper=[0,0.785,0.890275,6.443702104245254
]
Bayes=[0,0.789,0.88805,6.325708590132482

]
Ax=[0,0.817,0.885175,6.133054804498614

]
NG=[0,0.8,0.884825,6.290438322234702

]
BOHB=[0,0.785,0.8876999999999999,6.173551552576356


]
Ran=[0,0.787,0.884175,6.170678868638696

]
Zoo=[0,0.795,0.884625,6.325670890740688

]

# %%
plt.plot(t, mean_test_1, 'r-',label="HyperOptTest")
plt.plot(t, mean_test_2, 'c-',label="BayesOptTest")
plt.plot(t, mean_test_3, 'b-',label="AxTest")
plt.plot(t, mean_test_4, 'g-',label="NeverGradTest")
plt.plot(t, mean_test_5, 'k-',label="BOHBTest")
plt.plot(t, mean_test_6, 'm-',label="RandomTest")
plt.plot(t, mean_test_7, 'y-',label="ZooptTest")

# %%
plt.plot(bohb)

# %%
a=hyper[-20877::]
b=bayes[4630::]
c=ax[998::]
d=ng[41::]
e=bohb[::]
f=ran[42::]
g=10-zoo[7986::]

# %%
a=split(a,7077,13873).T
b=split(b,7028,14103).T
c=split(c,7126,14206).T
d=split(d,5935,11900).T
e=split(e,6071,11721).T
f=split(f,6254,12424).T
g=split(g,7018,14053).T

# %%
def splitl(x,a,b):
    n=7500
    c=np.array(x[0:a])
    d=np.array(x[a:b])
    f=np.array(x[b:])
    return c,d,f

# %%
def split(x,a,b):
    n=7500
    c=np.array(x[0:a])
    d=np.array(x[a:b])
    f=np.array(x[b:])
    c.resize(n)
    d.resize(n)
    f.resize(n)
    return np.array((c+np.zeros((n)),d
                     +np.zeros((n)), f+np.zeros((n))))

# %%
a1,a2,a3=splitl(a,7077,13872)
b1,b2,b3=splitl(b,7028,14103)
c1,c2,c3=splitl(c,7126,14206)
d1,d2,d3=splitl(d,5935,11900)
e1,e2,e3=splitl(e,6071,11721)
f1,f2,f3=splitl(f,6254,12424)
g1,g2,g3=splitl(g,7018,14053)

# %%
axes = plt.gca()
axes.set_ylim(1,7)
plt.plot(a1,alpha=0.4,color='k',label="Hyper training's IS")
plt.plot(a2,alpha=0.4,color='k')
plt.plot(a3,alpha=0.4,color='k')
plt.legend(bbox_to_anchor=(0.005,0.995 ), loc='upper left', borderaxespad=0.,ncol = 1)
#plt.yscale('log')
axes.set_xlabel('number of trainings')
axes.set_ylabel('Inception Score')
plt.savefig('new/906.png')

# %%
axes = plt.gca()
axes.set_ylim(1,7)
plt.plot(b1,alpha=0.4,color='k',label="Bayes training's IS")
plt.plot(b2,alpha=0.4,color='k')
plt.plot(b3,alpha=0.4,color='k')
plt.legend(bbox_to_anchor=(0.005,0.995 ), loc='upper left', borderaxespad=0.,ncol = 1)
#plt.yscale('log')
axes.set_xlabel('number of trainings')
axes.set_ylabel('Inception Score')
plt.savefig('new/907.png')

# %%
axes = plt.gca()
axes.set_ylim(1,7)
plt.plot(c1,alpha=0.4,color='k',label="NeverGrad training's IS")
plt.plot(c2,alpha=0.4,color='k')
plt.plot(c3,alpha=0.4,color='k')
plt.legend(bbox_to_anchor=(0.005,0.995 ), loc='upper left', borderaxespad=0.,ncol = 1)
#plt.yscale('log')
axes.set_xlabel('number of trainings')
axes.set_ylabel('Inception Score')
plt.savefig('new/908.png')

# %%
plt.plot(f1,alpha=0.4,color='k')
plt.plot(f2,alpha=0.4,color='k')
plt.plot(f3,alpha=0.4,color='k')

# %%
import matplotlib.pyplot as plt

plt.plot(a)
plt.show()
plt.plot(b)
plt.show()
plt.plot(c)
plt.show()
plt.plot(d)
plt.show()
plt.plot(e)
plt.show()
plt.plot(f)
plt.show()
plt.plot(g)
plt.show()

# %%
hyper = a

bayes =b

ax = c

ng = d

bohb = e

ran = f

zoo =  g


def minof(a):
    for j in range(3):
        ma = 0;
        for i in range(7500):
            ma = max(ma,a[i,j]) 
            a[i,j] = ma
        
def all(x):
    minof(x)
    return x
        
hyper = all(hyper)
bayes = all(bayes)
ng = all(ng)
ax = all(ax)
bohb = all(bohb)
ran = all(ran)
zoo = all(zoo)
        

def getall(a):
    f = [b for b in a.mean(1)]
    return (f, a.std(1)/2)

# %%
t = np.arange(7500)
mean_test_1,std_test_1 = getall(hyper)
mean_test_2,std_test_2 = getall(bayes)
mean_test_3,std_test_3 = getall(ax)
mean_test_4,std_test_4 = getall(ng)
mean_test_5,std_test_5= getall(bohb)
mean_test_6,std_test_6 = getall(ran)
mean_test_7,std_test_7 = getall(zoo)

all_m_t=np.array((mean_test_1,mean_test_2,mean_test_3,mean_test_4,
                        mean_test_5,mean_test_6,mean_test_7))
all_m_t = all_m_t.mean(0)


plt.plot(t, all_m_t, 'r-',label="test_mean accuracy")

#plt.fill_between(t, mean-std, mean+std, alpha = 0.5)


#plt.plot(t, meant, 'k-',label="BayesOpt")

#plt.fill_between(t, meant-stdt, meant+stdt, alpha = 0.5)

#plt.plot(t, ZZ1, '',label="inversedZoopt")
axes = plt.gca()
axes.set_ylim(1,10)
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 1)
plt.savefig('113.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_1, 'r-',label="HyperOpt")
plt.plot(t, mean_test_2, 'c-',label="BayesOpt")
plt.plot(t, mean_test_3, 'b-',label="Ax")
plt.plot(t, mean_test_4, 'g-',label="NeverGrad")
plt.plot(t, mean_test_5, 'k-',label="TwoPointsDE")
plt.plot(t, mean_test_6, 'm-',label="Random")
plt.plot(t, mean_test_7, 'y-',label="Zoopt")

axes = plt.gca()
axes.set_ylim(1,6.5)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 3)
#plt.yscale('log')
axes.set_xlabel('number of trainings')
axes.set_ylabel('Inception Score')
plt.savefig('new/901.png')

#plt.title(r'\underline{Validation loss}:')
fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_1, 'r-',label="HyperOpt")
plt.plot(t, mean_test_2, 'c-',label="BayesOpt")
plt.plot(t, mean_test_3, 'b-',label="Ax")
plt.plot(t, mean_test_4, 'g-',label="NeverGrad")
plt.plot(t, mean_test_5, 'k-',label="TwoPointsDE")
plt.plot(t, mean_test_6, 'm-',label="Random")
plt.plot(t, mean_test_7, 'y-',label="Zoopt")

axes = plt.gca()
axes.set_ylim(5.2,6.5)
#plt.axis([0, 260,0 ,0.85 ])
#plt.yscale('log')
axes.set_xlabel('number of trainings')
axes.set_ylabel('Inception Score')
plt.savefig('new/900.png')

#plt.title(r'\underline{Validation loss}:')
fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_val_1, 'r-',label="HyperOpt")
plt.plot(t, mean_val_2, 'c-',label="BayesOpt")
plt.plot(t, mean_val_3, 'b-',label="Ax")
plt.plot(t, mean_val_4, 'g-',label="NeverGrad")
plt.plot(t, mean_val_5, 'k-',label="BOHB")
plt.plot(t, mean_val_6, 'm-',label="Random")
plt.plot(t, mean_val_7, 'y-',label="Zoopt")

axes = plt.gca()
axes.set_ylim(5,7)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('val accuracy')
plt.savefig('new/2.png')

#plt.title(r'\underline{Validation loss}:')
fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_1, 'r-',label="HyperOptTest")
plt.plot(t, mean_test_2, 'c-',label="BayesOptTest")
plt.plot(t, mean_test_3, 'b-',label="AxTest")
plt.plot(t, mean_test_4, 'g-',label="NeverGradTest")
plt.plot(t, mean_test_5, 'k-',label="BOHBTest")
plt.plot(t, mean_test_6, 'm-',label="RandomTest")
plt.plot(t, mean_test_7, 'y-',label="ZooptTest")
plt.plot(t, mean_val_1, 'r--',label="HyperOptVal")
plt.plot(t, mean_val_2, 'c--',label="BayesOptVal")
plt.plot(t, mean_val_3, 'b--',label="AxVal")
plt.plot(t, mean_val_4, 'g--',label="NeverGradVal")
plt.plot(t, mean_val_5, 'k--',label="BOHBVal")
plt.plot(t, mean_val_6, 'm--',label="RandomVal")
plt.plot(t, mean_val_7, 'y--',label="ZooptVam")

axes = plt.gca()
axes.set_ylim(0.815,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(1.005,0.005 ), loc='lower left', borderaxespad=0.,ncol = 1)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('loss')
#plt.title(r'\underline{Validation loss}:')
plt.tight_layout()
plt.savefig('916.png')
fig = plt.figure()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d34ff9bc59fc> in <module>
#       6 plt.plot(t, mean_test_6, 'm-',label="RandomTest")
#       7 plt.plot(t, mean_test_7, 'y-',label="ZooptTest")
# ----> 8 plt.plot(t, mean_val_1, 'r--',label="HyperOptVal")
#       9 plt.plot(t, mean_val_2, 'c--',label="BayesOptVal")
#      10 plt.plot(t, mean_val_3, 'b--',label="AxVal")
#
# NameError: name 'mean_val_1' is not defined

# %%
all_m_t=np.array((mean_test_1,mean_test_2,mean_test_3,mean_test_4,
                        mean_test_5,mean_test_7))
all_m_t = all_m_t.max(0)


plt.plot(t, all_m_t, 'b-',label="test learning")


plt.plot(t, mean_test_6, 'r-',label="test random")


#plt.fill_between(t, mean-std, mean+std, alpha = 0.5)


#plt.plot(t, meant, 'k-',label="BayesOpt")

#plt.fill_between(t, meant-stdt, meant+stdt, alpha = 0.5)

#plt.plot(t, ZZ1, '',label="inversedZoopt")
axes = plt.gca()
axes.set_ylim(1,7)
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('loss')
#plt.title(r'\underline{Validation loss}:')
plt.savefig('117.png')

fig = plt.figure()
plt.show()

# %%
all_m_t1=np.array((mean_test_1,mean_test_2,mean_test_3,mean_test_4,
                        mean_test_5,mean_test_7))
all_m_t = all_m_t1.max(0)
all_m_s = all_m_t1.std(0)/2


plt.plot(t, all_m_t, 'b-',label="test learning")
plt.fill_between(t, all_m_t-all_m_s,  all_m_t+all_m_s, alpha = 0.2,color='b')


plt.plot(t, mean_test_6, 'r-',label="test random")
plt.fill_between(t, mean_test_6-std_test_6,  mean_test_6+std_test_6, alpha = 0.2,color='r')



#plt.fill_between(t, mean-std, mean+std, alpha = 0.5)


#plt.plot(t, meant, 'k-',label="BayesOpt")

#plt.fill_between(t, meant-stdt, meant+stdt, alpha = 0.5)

#plt.plot(t, ZZ1, '',label="inversedZoopt")
axes = plt.gca()
axes.set_ylim(1,7)
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/903.png')

#plt.title(r'\underline{Validation loss}:')
fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_4, 'k-',label="test NeverGrad")
plt.fill_between(t, mean_test_4-std_test_4,  mean_test_4+std_test_4, alpha = 0.2,color='k')

plt.plot(t, mean_val_4, 'k--',label="val NeverGrad")
plt.fill_between(t, mean_val_4-std_val_4,  mean_val_4+std_val_4, alpha = 0.2,color='k')

plt.plot(t, mean_test_6, 'r-',label="test random")
plt.fill_between(t, mean_test_6-std_test_6,  mean_test_6+std_test_6, alpha = 0.2,color='r')

plt.plot(t, mean_val_6, 'r--',label="val random")
plt.fill_between(t, mean_val_6-std_val_6,  mean_val_6+std_val_6, alpha = 0.2,color='r')


axes = plt.gca()
axes.set_ylim(0.78,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('loss')
plt.savefig('109.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(a)


axes = plt.gca()
axes.set_ylim(0,7)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/904.png')

fig = plt.figure()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(t, mean_test_1, 'r-',label="hyper")
plt.fill_between(t, mean_test_1-std_test_1,  mean_test_1+std_test_1, alpha = 0.2,color='r')
plt.plot(t, mean_test_3, 'b-',label="ax")
plt.fill_between(t, mean_test_3-std_test_3,  mean_test_3+std_test_3, alpha = 0.2,color='b')
plt.plot(t, mean_test_6, 'm-',label="random")
plt.fill_between(t, mean_test_6-std_test_6,  mean_test_6+std_test_6, alpha = 0.2,color='m')
plt.plot(t, mean_test_7, 'y-',label="zoopt")
plt.fill_between(t, mean_test_7-std_test_7,  mean_test_7+std_test_7, alpha = 0.2,color='y')


axes = plt.gca()
axes.set_ylim(4.8,6.6)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.005,0.995 ), loc='upper left', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trainings')
axes.set_ylabel('Inception Score')
plt.savefig('new/904.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_2, 'c-',label="bayes")
plt.fill_between(t, mean_test_2-std_test_2,  mean_test_2+std_test_2, alpha = 0.2,color='c')
plt.plot(t, mean_test_4, 'g-',label="NG")
plt.fill_between(t, mean_test_4-std_test_4,  mean_test_4+std_test_4, alpha = 0.2,color='g')
plt.plot(t, mean_test_5, 'k-',label="2PointsDe ")
plt.fill_between(t, mean_test_5-std_test_5,  mean_test_5+std_test_5, alpha = 0.2,color='k')


axes = plt.gca()
axes.set_ylim(4.8,6.6)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.005,0.995 ), loc='upper left', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trainings')
axes.set_ylabel('Inception Score')
plt.savefig('new/905.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_3, 'k-',label="test ax")
plt.fill_between(t, mean_test_3-std_test_3,  mean_test_3+std_test_3, alpha = 0.2,color='k')

plt.plot(t, mean_val_3, 'b--',label="val ax")
plt.fill_between(t, mean_val_3-std_val_3,  mean_val_3+std_val_3, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.78,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/5.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_4, 'k-',label="test NeverGrad")
plt.fill_between(t, mean_test_4-std_test_4,  mean_test_4+std_test_4, alpha = 0.2,color='k')

plt.plot(t, mean_val_4, 'b--',label="val NeverGrad")
plt.fill_between(t, mean_val_4-std_val_4,  mean_val_4+std_val_4, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.006,0.018)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/124.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_5, 'k-',label="test bohb")
plt.fill_between(t, mean_test_5-std_test_5,  mean_test_5+std_test_5, alpha = 0.2,color='k')

plt.plot(t, mean_val_5, 'b--',label="val bohb")
plt.fill_between(t, mean_val_5-std_val_5,  mean_val_5+std_val_5, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.78,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('accuracy')
plt.savefig('new/6.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_6, 'k-',label="test random")
plt.fill_between(t, mean_test_6-std_test_6,  mean_test_6+std_test_6, alpha = 0.2,color='k')

plt.plot(t, mean_val_6, 'b--',label="val random")
plt.fill_between(t, mean_val_6-std_val_6,  mean_val_6+std_val_6, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.78,0.902)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.005 ), loc='lower right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/7.png')

fig = plt.figure()
plt.show()

# %%
plt.plot(t, mean_test_7, 'k-',label="test zoopt")
plt.fill_between(t, mean_test_7-std_test_7,  mean_test_7+std_test_7, alpha = 0.2,color='k')

plt.plot(t, mean_val_7, 'b--',label="val zoopt")
plt.fill_between(t, mean_val_7-std_val_7,  mean_val_7+std_val_7, alpha = 0.2,color='b')


axes = plt.gca()
axes.set_ylim(0.006,0.018)
#plt.axis([0, 260,0 ,0.85 ])
plt.legend(bbox_to_anchor=(0.995,0.995 ), loc='upper right', borderaxespad=0.,ncol = 2)
#plt.yscale('log')
axes.set_xlabel('number of trials')
axes.set_ylabel('MSE')
plt.savefig('new/127.png')

fig = plt.figure()
plt.show()
